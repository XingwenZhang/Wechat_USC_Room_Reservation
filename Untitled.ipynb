# %%
from bs4 import BeautifulSoup
import requests

# %%
html = requests.get('http://libcal.usc.edu/rooms_acc.php?gid=4490&d=2017-7-25&cap=1')

# %%
soup = BeautifulSoup(html.text,'lxml')

# %%
for item in soup.find('select').stripped_strings:
    print(item)
# Out:
# Wednesday, July 19th
# Thursday, July 20th
# Friday, July 21st
# Saturday, July 22nd
# Sunday, July 23rd
# Monday, July 24th
# Tuesday, July 25th
# Wednesday, July 26th

# %%
book_room_form = soup.find('form',id = 'roombookingform')

# %%
<div id="s-lc-rm-tc-box" class="s-lc-rm-box"><p>Groups have priority. If you make a reservation as an individual, a group may ask you to relocate.<em>(Except for the MMPL iMac Workstations)</em></p>
<p>Each reservation has a 10 minute grace period. If your group has not arrived after the first 10 minutes of your reservation have passed, another group may take over your reservation.<em></em></p>
<p><span style="font-size: small;"><strong><span style="font-size: x-small;">NOTE: If furniture or equipment is lost or damaged while you are in the room, you may be charged for repair or replacement.</span><br></strong></span></p>
<p><span style="font-size: small;"><strong>&nbsp;</strong></span></p></div>
# Out:
#   File "<ipython-input-183-3bffed47deaa>", line 1
#     <div id="s-lc-rm-tc-box" class="s-lc-rm-box"><p>Groups have priority. If you make a reservation as an individual, a group may ask you to relocate.<em>(Except for the MMPL iMac Workstations)</em></p>
#     ^
# SyntaxError: invalid syntax

# %%
book_room_form.find('div',id='s-lc-rm-tc-box').decompose()

# %%
book_room_form.findAll('fieldset')[-1].decompose()

# %%
for item in book_room_form.findAll('small'):
    item.decompose()

# %%
for item in book_room_form.findAll('legend'):
    item.next_sibling.decompose()

# %%
for item in book_room_form.find_all('a', class_ = "sr-only"):
    item.decompose()

# %%
# Out:
# <form class="form-horizontal" id="roombookingform" method="POST" role="form">
# <input name="gid" type="hidden" value="4490"/><fieldset class="s-lc-rm-cap-l-1"><legend><h2>3F </h2></legend><div class="checkbox">
# <label for="sch545454782">
# <input class="durc" data-seq="12616101" id="sch545454782" name="sid[]" onchange="checkDur('545454782');" type="checkbox" value="545454782"/>
# 						9:00am - 10:00am
# 					  </label>
# </div><input id="sch545454782dur" name="dur545454782" type="hidden" value="60"/><input id="t_sch545454782" name="t_sch545454782" type="hidden" value="3F 9:00am - 10:00am Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454783">
# <input class="durc" data-seq="12616102" id="sch545454783" name="sid[]" onchange="checkDur('545454783');" type="checkbox" value="545454783"/>
# 						10:00am - 11:00am
# 					  </label>
# </div><input id="sch545454783dur" name="dur545454783" type="hidden" value="60"/><input id="t_sch545454783" name="t_sch545454783" type="hidden" value="3F 10:00am - 11:00am Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454784">
# <input class="durc" data-seq="12616103" id="sch545454784" name="sid[]" onchange="checkDur('545454784');" type="checkbox" value="545454784"/>
# 						11:00am - 12:00pm
# 					  </label>
# </div><input id="sch545454784dur" name="dur545454784" type="hidden" value="60"/><input id="t_sch545454784" name="t_sch545454784" type="hidden" value="3F 11:00am - 12:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454785">
# <input class="durc" data-seq="12616104" id="sch545454785" name="sid[]" onchange="checkDur('545454785');" type="checkbox" value="545454785"/>
# 						12:00pm - 1:00pm
# 					  </label>
# </div><input id="sch545454785dur" name="dur545454785" type="hidden" value="60"/><input id="t_sch545454785" name="t_sch545454785" type="hidden" value="3F 12:00pm - 1:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454786">
# <input class="durc" data-seq="12616105" id="sch545454786" name="sid[]" onchange="checkDur('545454786');" type="checkbox" value="545454786"/>
# 						1:00pm - 2:00pm
# 					  </label>
# </div><input id="sch545454786dur" name="dur545454786" type="hidden" value="60"/><input id="t_sch545454786" name="t_sch545454786" type="hidden" value="3F 1:00pm - 2:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch548615161">
# <input class="durc" data-seq="12616110" id="sch548615161" name="sid[]" onchange="checkDur('548615161');" type="checkbox" value="548615161"/>
# 						6:00pm - 7:00pm
# 					  </label>
# </div><input id="sch548615161dur" name="dur548615161" type="hidden" value="60"/><input id="t_sch548615161" name="t_sch548615161" type="hidden" value="3F 6:00pm - 7:00pm Friday, July 21, 2017"/></fieldset><fieldset class="s-lc-rm-cap-l-1"><legend><h2>3G </h2></legend><div class="checkbox">
# <label for="sch545454777">
# <input class="durc" data-seq="12617103" id="sch545454777" name="sid[]" onchange="checkDur('545454777');" type="checkbox" value="545454777"/>
# 						11:00am - 12:00pm
# 					  </label>
# </div><input id="sch545454777dur" name="dur545454777" type="hidden" value="60"/><input id="t_sch545454777" name="t_sch545454777" type="hidden" value="3G 11:00am - 12:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454778">
# <input class="durc" data-seq="12617104" id="sch545454778" name="sid[]" onchange="checkDur('545454778');" type="checkbox" value="545454778"/>
# 						12:00pm - 1:00pm
# 					  </label>
# </div><input id="sch545454778dur" name="dur545454778" type="hidden" value="60"/><input id="t_sch545454778" name="t_sch545454778" type="hidden" value="3G 12:00pm - 1:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454779">
# <input class="durc" data-seq="12617105" id="sch545454779" name="sid[]" onchange="checkDur('545454779');" type="checkbox" value="545454779"/>
# 						1:00pm - 2:00pm
# 					  </label>
# </div><input id="sch545454779dur" name="dur545454779" type="hidden" value="60"/><input id="t_sch545454779" name="t_sch545454779" type="hidden" value="3G 1:00pm - 2:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454780">
# <input class="durc" data-seq="12617106" id="sch545454780" name="sid[]" onchange="checkDur('545454780');" type="checkbox" value="545454780"/>
# 						2:00pm - 3:00pm
# 					  </label>
# </div><input id="sch545454780dur" name="dur545454780" type="hidden" value="60"/><input id="t_sch545454780" name="t_sch545454780" type="hidden" value="3G 2:00pm - 3:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454781">
# <input class="durc" data-seq="12617107" id="sch545454781" name="sid[]" onchange="checkDur('545454781');" type="checkbox" value="545454781"/>
# 						3:00pm - 4:00pm
# 					  </label>
# </div><input id="sch545454781dur" name="dur545454781" type="hidden" value="60"/><input id="t_sch545454781" name="t_sch545454781" type="hidden" value="3G 3:00pm - 4:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch548615156">
# <input class="durc" data-seq="12617108" id="sch548615156" name="sid[]" onchange="checkDur('548615156');" type="checkbox" value="548615156"/>
# 						4:00pm - 5:00pm
# 					  </label>
# </div><input id="sch548615156dur" name="dur548615156" type="hidden" value="60"/><input id="t_sch548615156" name="t_sch548615156" type="hidden" value="3G 4:00pm - 5:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch548615157">
# <input class="durc" data-seq="12617109" id="sch548615157" name="sid[]" onchange="checkDur('548615157');" type="checkbox" value="548615157"/>
# 						5:00pm - 6:00pm
# 					  </label>
# </div><input id="sch548615157dur" name="dur548615157" type="hidden" value="60"/><input id="t_sch548615157" name="t_sch548615157" type="hidden" value="3G 5:00pm - 6:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch548615158">
# <input class="durc" data-seq="12617110" id="sch548615158" name="sid[]" onchange="checkDur('548615158');" type="checkbox" value="548615158"/>
# 						6:00pm - 7:00pm
# 					  </label>
# </div><input id="sch548615158dur" name="dur548615158" type="hidden" value="60"/><input id="t_sch548615158" name="t_sch548615158" type="hidden" value="3G 6:00pm - 7:00pm Friday, July 21, 2017"/></fieldset><fieldset class="s-lc-rm-cap-l-1"><legend><h2>3H </h2></legend><div class="checkbox">
# <label for="sch545454768">
# <input class="durc" data-seq="12618101" id="sch545454768" name="sid[]" onchange="checkDur('545454768');" type="checkbox" value="545454768"/>
# 						9:00am - 10:00am
# 					  </label>
# </div><input id="sch545454768dur" name="dur545454768" type="hidden" value="60"/><input id="t_sch545454768" name="t_sch545454768" type="hidden" value="3H 9:00am - 10:00am Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454769">
# <input class="durc" data-seq="12618102" id="sch545454769" name="sid[]" onchange="checkDur('545454769');" type="checkbox" value="545454769"/>
# 						10:00am - 11:00am
# 					  </label>
# </div><input id="sch545454769dur" name="dur545454769" type="hidden" value="60"/><input id="t_sch545454769" name="t_sch545454769" type="hidden" value="3H 10:00am - 11:00am Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454770">
# <input class="durc" data-seq="12618103" id="sch545454770" name="sid[]" onchange="checkDur('545454770');" type="checkbox" value="545454770"/>
# 						11:00am - 12:00pm
# 					  </label>
# </div><input id="sch545454770dur" name="dur545454770" type="hidden" value="60"/><input id="t_sch545454770" name="t_sch545454770" type="hidden" value="3H 11:00am - 12:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454771">
# <input class="durc" data-seq="12618104" id="sch545454771" name="sid[]" onchange="checkDur('545454771');" type="checkbox" value="545454771"/>
# 						12:00pm - 1:00pm
# 					  </label>
# </div><input id="sch545454771dur" name="dur545454771" type="hidden" value="60"/><input id="t_sch545454771" name="t_sch545454771" type="hidden" value="3H 12:00pm - 1:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454772">
# <input class="durc" data-seq="12618105" id="sch545454772" name="sid[]" onchange="checkDur('545454772');" type="checkbox" value="545454772"/>
# 						1:00pm - 2:00pm
# 					  </label>
# </div><input id="sch545454772dur" name="dur545454772" type="hidden" value="60"/><input id="t_sch545454772" name="t_sch545454772" type="hidden" value="3H 1:00pm - 2:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454773">
# <input class="durc" data-seq="12618106" id="sch545454773" name="sid[]" onchange="checkDur('545454773');" type="checkbox" value="545454773"/>
# 						2:00pm - 3:00pm
# 					  </label>
# </div><input id="sch545454773dur" name="dur545454773" type="hidden" value="60"/><input id="t_sch545454773" name="t_sch545454773" type="hidden" value="3H 2:00pm - 3:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454774">
# <input class="durc" data-seq="12618107" id="sch545454774" name="sid[]" onchange="checkDur('545454774');" type="checkbox" value="545454774"/>
# 						3:00pm - 4:00pm
# 					  </label>
# </div><input id="sch545454774dur" name="dur545454774" type="hidden" value="60"/><input id="t_sch545454774" name="t_sch545454774" type="hidden" value="3H 3:00pm - 4:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch548615153">
# <input class="durc" data-seq="12618108" id="sch548615153" name="sid[]" onchange="checkDur('548615153');" type="checkbox" value="548615153"/>
# 						4:00pm - 5:00pm
# 					  </label>
# </div><input id="sch548615153dur" name="dur548615153" type="hidden" value="60"/><input id="t_sch548615153" name="t_sch548615153" type="hidden" value="3H 4:00pm - 5:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch548615154">
# <input class="durc" data-seq="12618109" id="sch548615154" name="sid[]" onchange="checkDur('548615154');" type="checkbox" value="548615154"/>
# 						5:00pm - 6:00pm
# 					  </label>
# </div><input id="sch548615154dur" name="dur548615154" type="hidden" value="60"/><input id="t_sch548615154" name="t_sch548615154" type="hidden" value="3H 5:00pm - 6:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch548615155">
# <input class="durc" data-seq="12618110" id="sch548615155" name="sid[]" onchange="checkDur('548615155');" type="checkbox" value="548615155"/>
# 						6:00pm - 7:00pm
# 					  </label>
# </div><input id="sch548615155dur" name="dur548615155" type="hidden" value="60"/><input id="t_sch548615155" name="t_sch548615155" type="hidden" value="3H 6:00pm - 7:00pm Friday, July 21, 2017"/></fieldset><fieldset class="s-lc-rm-cap-l-1"><legend><h2>3J </h2></legend><div class="checkbox">
# <label for="sch545454761">
# <input class="durc" data-seq="12619101" id="sch545454761" name="sid[]" onchange="checkDur('545454761');" type="checkbox" value="545454761"/>
# 						9:00am - 10:00am
# 					  </label>
# </div><input id="sch545454761dur" name="dur545454761" type="hidden" value="60"/><input id="t_sch545454761" name="t_sch545454761" type="hidden" value="3J 9:00am - 10:00am Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454762">
# <input class="durc" data-seq="12619102" id="sch545454762" name="sid[]" onchange="checkDur('545454762');" type="checkbox" value="545454762"/>
# 						10:00am - 11:00am
# 					  </label>
# </div><input id="sch545454762dur" name="dur545454762" type="hidden" value="60"/><input id="t_sch545454762" name="t_sch545454762" type="hidden" value="3J 10:00am - 11:00am Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454763">
# <input class="durc" data-seq="12619103" id="sch545454763" name="sid[]" onchange="checkDur('545454763');" type="checkbox" value="545454763"/>
# 						11:00am - 12:00pm
# 					  </label>
# </div><input id="sch545454763dur" name="dur545454763" type="hidden" value="60"/><input id="t_sch545454763" name="t_sch545454763" type="hidden" value="3J 11:00am - 12:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454764">
# <input class="durc" data-seq="12619104" id="sch545454764" name="sid[]" onchange="checkDur('545454764');" type="checkbox" value="545454764"/>
# 						12:00pm - 1:00pm
# 					  </label>
# </div><input id="sch545454764dur" name="dur545454764" type="hidden" value="60"/><input id="t_sch545454764" name="t_sch545454764" type="hidden" value="3J 12:00pm - 1:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454765">
# <input class="durc" data-seq="12619105" id="sch545454765" name="sid[]" onchange="checkDur('545454765');" type="checkbox" value="545454765"/>
# 						1:00pm - 2:00pm
# 					  </label>
# </div><input id="sch545454765dur" name="dur545454765" type="hidden" value="60"/><input id="t_sch545454765" name="t_sch545454765" type="hidden" value="3J 1:00pm - 2:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454766">
# <input class="durc" data-seq="12619106" id="sch545454766" name="sid[]" onchange="checkDur('545454766');" type="checkbox" value="545454766"/>
# 						2:00pm - 3:00pm
# 					  </label>
# </div><input id="sch545454766dur" name="dur545454766" type="hidden" value="60"/><input id="t_sch545454766" name="t_sch545454766" type="hidden" value="3J 2:00pm - 3:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454767">
# <input class="durc" data-seq="12619107" id="sch545454767" name="sid[]" onchange="checkDur('545454767');" type="checkbox" value="545454767"/>
# 						3:00pm - 4:00pm
# 					  </label>
# </div><input id="sch545454767dur" name="dur545454767" type="hidden" value="60"/><input id="t_sch545454767" name="t_sch545454767" type="hidden" value="3J 3:00pm - 4:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch548615150">
# <input class="durc" data-seq="12619108" id="sch548615150" name="sid[]" onchange="checkDur('548615150');" type="checkbox" value="548615150"/>
# 						4:00pm - 5:00pm
# 					  </label>
# </div><input id="sch548615150dur" name="dur548615150" type="hidden" value="60"/><input id="t_sch548615150" name="t_sch548615150" type="hidden" value="3J 4:00pm - 5:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch548615151">
# <input class="durc" data-seq="12619109" id="sch548615151" name="sid[]" onchange="checkDur('548615151');" type="checkbox" value="548615151"/>
# 						5:00pm - 6:00pm
# 					  </label>
# </div><input id="sch548615151dur" name="dur548615151" type="hidden" value="60"/><input id="t_sch548615151" name="t_sch548615151" type="hidden" value="3J 5:00pm - 6:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch548615152">
# <input class="durc" data-seq="12619110" id="sch548615152" name="sid[]" onchange="checkDur('548615152');" type="checkbox" value="548615152"/>
# 						6:00pm - 7:00pm
# 					  </label>
# </div><input id="sch548615152dur" name="dur548615152" type="hidden" value="60"/><input id="t_sch548615152" name="t_sch548615152" type="hidden" value="3J 6:00pm - 7:00pm Friday, July 21, 2017"/></fieldset><fieldset class="s-lc-rm-cap-l-1"><legend><h2>3R </h2></legend><div class="checkbox">
# <label for="sch545454754">
# <input class="durc" data-seq="12620101" id="sch545454754" name="sid[]" onchange="checkDur('545454754');" type="checkbox" value="545454754"/>
# 						9:00am - 10:00am
# 					  </label>
# </div><input id="sch545454754dur" name="dur545454754" type="hidden" value="60"/><input id="t_sch545454754" name="t_sch545454754" type="hidden" value="3R 9:00am - 10:00am Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454755">
# <input class="durc" data-seq="12620102" id="sch545454755" name="sid[]" onchange="checkDur('545454755');" type="checkbox" value="545454755"/>
# 						10:00am - 11:00am
# 					  </label>
# </div><input id="sch545454755dur" name="dur545454755" type="hidden" value="60"/><input id="t_sch545454755" name="t_sch545454755" type="hidden" value="3R 10:00am - 11:00am Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454756">
# <input class="durc" data-seq="12620103" id="sch545454756" name="sid[]" onchange="checkDur('545454756');" type="checkbox" value="545454756"/>
# 						11:00am - 12:00pm
# 					  </label>
# </div><input id="sch545454756dur" name="dur545454756" type="hidden" value="60"/><input id="t_sch545454756" name="t_sch545454756" type="hidden" value="3R 11:00am - 12:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454757">
# <input class="durc" data-seq="12620104" id="sch545454757" name="sid[]" onchange="checkDur('545454757');" type="checkbox" value="545454757"/>
# 						12:00pm - 1:00pm
# 					  </label>
# </div><input id="sch545454757dur" name="dur545454757" type="hidden" value="60"/><input id="t_sch545454757" name="t_sch545454757" type="hidden" value="3R 12:00pm - 1:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454758">
# <input class="durc" data-seq="12620105" id="sch545454758" name="sid[]" onchange="checkDur('545454758');" type="checkbox" value="545454758"/>
# 						1:00pm - 2:00pm
# 					  </label>
# </div><input id="sch545454758dur" name="dur545454758" type="hidden" value="60"/><input id="t_sch545454758" name="t_sch545454758" type="hidden" value="3R 1:00pm - 2:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454759">
# <input class="durc" data-seq="12620106" id="sch545454759" name="sid[]" onchange="checkDur('545454759');" type="checkbox" value="545454759"/>
# 						2:00pm - 3:00pm
# 					  </label>
# </div><input id="sch545454759dur" name="dur545454759" type="hidden" value="60"/><input id="t_sch545454759" name="t_sch545454759" type="hidden" value="3R 2:00pm - 3:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454760">
# <input class="durc" data-seq="12620107" id="sch545454760" name="sid[]" onchange="checkDur('545454760');" type="checkbox" value="545454760"/>
# 						3:00pm - 4:00pm
# 					  </label>
# </div><input id="sch545454760dur" name="dur545454760" type="hidden" value="60"/><input id="t_sch545454760" name="t_sch545454760" type="hidden" value="3R 3:00pm - 4:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch548615148">
# <input class="durc" data-seq="12620109" id="sch548615148" name="sid[]" onchange="checkDur('548615148');" type="checkbox" value="548615148"/>
# 						5:00pm - 6:00pm
# 					  </label>
# </div><input id="sch548615148dur" name="dur548615148" type="hidden" value="60"/><input id="t_sch548615148" name="t_sch548615148" type="hidden" value="3R 5:00pm - 6:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch548615149">
# <input class="durc" data-seq="12620110" id="sch548615149" name="sid[]" onchange="checkDur('548615149');" type="checkbox" value="548615149"/>
# 						6:00pm - 7:00pm
# 					  </label>
# </div><input id="sch548615149dur" name="dur548615149" type="hidden" value="60"/><input id="t_sch548615149" name="t_sch548615149" type="hidden" value="3R 6:00pm - 7:00pm Friday, July 21, 2017"/></fieldset><fieldset class="s-lc-rm-cap-l-1"><legend><h2>3S </h2></legend><div class="checkbox">
# <label for="sch545454747">
# <input class="durc" data-seq="12621101" id="sch545454747" name="sid[]" onchange="checkDur('545454747');" type="checkbox" value="545454747"/>
# 						9:00am - 10:00am
# 					  </label>
# </div><input id="sch545454747dur" name="dur545454747" type="hidden" value="60"/><input id="t_sch545454747" name="t_sch545454747" type="hidden" value="3S 9:00am - 10:00am Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454748">
# <input class="durc" data-seq="12621102" id="sch545454748" name="sid[]" onchange="checkDur('545454748');" type="checkbox" value="545454748"/>
# 						10:00am - 11:00am
# 					  </label>
# </div><input id="sch545454748dur" name="dur545454748" type="hidden" value="60"/><input id="t_sch545454748" name="t_sch545454748" type="hidden" value="3S 10:00am - 11:00am Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454749">
# <input class="durc" data-seq="12621103" id="sch545454749" name="sid[]" onchange="checkDur('545454749');" type="checkbox" value="545454749"/>
# 						11:00am - 12:00pm
# 					  </label>
# </div><input id="sch545454749dur" name="dur545454749" type="hidden" value="60"/><input id="t_sch545454749" name="t_sch545454749" type="hidden" value="3S 11:00am - 12:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454750">
# <input class="durc" data-seq="12621104" id="sch545454750" name="sid[]" onchange="checkDur('545454750');" type="checkbox" value="545454750"/>
# 						12:00pm - 1:00pm
# 					  </label>
# </div><input id="sch545454750dur" name="dur545454750" type="hidden" value="60"/><input id="t_sch545454750" name="t_sch545454750" type="hidden" value="3S 12:00pm - 1:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454751">
# <input class="durc" data-seq="12621105" id="sch545454751" name="sid[]" onchange="checkDur('545454751');" type="checkbox" value="545454751"/>
# 						1:00pm - 2:00pm
# 					  </label>
# </div><input id="sch545454751dur" name="dur545454751" type="hidden" value="60"/><input id="t_sch545454751" name="t_sch545454751" type="hidden" value="3S 1:00pm - 2:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454752">
# <input class="durc" data-seq="12621106" id="sch545454752" name="sid[]" onchange="checkDur('545454752');" type="checkbox" value="545454752"/>
# 						2:00pm - 3:00pm
# 					  </label>
# </div><input id="sch545454752dur" name="dur545454752" type="hidden" value="60"/><input id="t_sch545454752" name="t_sch545454752" type="hidden" value="3S 2:00pm - 3:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454753">
# <input class="durc" data-seq="12621107" id="sch545454753" name="sid[]" onchange="checkDur('545454753');" type="checkbox" value="545454753"/>
# 						3:00pm - 4:00pm
# 					  </label>
# </div><input id="sch545454753dur" name="dur545454753" type="hidden" value="60"/><input id="t_sch545454753" name="t_sch545454753" type="hidden" value="3S 3:00pm - 4:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch548615144">
# <input class="durc" data-seq="12621108" id="sch548615144" name="sid[]" onchange="checkDur('548615144');" type="checkbox" value="548615144"/>
# 						4:00pm - 5:00pm
# 					  </label>
# </div><input id="sch548615144dur" name="dur548615144" type="hidden" value="60"/><input id="t_sch548615144" name="t_sch548615144" type="hidden" value="3S 4:00pm - 5:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch548615145">
# <input class="durc" data-seq="12621109" id="sch548615145" name="sid[]" onchange="checkDur('548615145');" type="checkbox" value="548615145"/>
# 						5:00pm - 6:00pm
# 					  </label>
# </div><input id="sch548615145dur" name="dur548615145" type="hidden" value="60"/><input id="t_sch548615145" name="t_sch548615145" type="hidden" value="3S 5:00pm - 6:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch548615146">
# <input class="durc" data-seq="12621110" id="sch548615146" name="sid[]" onchange="checkDur('548615146');" type="checkbox" value="548615146"/>
# 						6:00pm - 7:00pm
# 					  </label>
# </div><input id="sch548615146dur" name="dur548615146" type="hidden" value="60"/><input id="t_sch548615146" name="t_sch548615146" type="hidden" value="3S 6:00pm - 7:00pm Friday, July 21, 2017"/></fieldset><fieldset class="s-lc-rm-cap-l-1"><legend><h2>3T </h2></legend><div class="checkbox">
# <label for="sch545454740">
# <input class="durc" data-seq="12622101" id="sch545454740" name="sid[]" onchange="checkDur('545454740');" type="checkbox" value="545454740"/>
# 						9:00am - 10:00am
# 					  </label>
# </div><input id="sch545454740dur" name="dur545454740" type="hidden" value="60"/><input id="t_sch545454740" name="t_sch545454740" type="hidden" value="3T 9:00am - 10:00am Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454741">
# <input class="durc" data-seq="12622102" id="sch545454741" name="sid[]" onchange="checkDur('545454741');" type="checkbox" value="545454741"/>
# 						10:00am - 11:00am
# 					  </label>
# </div><input id="sch545454741dur" name="dur545454741" type="hidden" value="60"/><input id="t_sch545454741" name="t_sch545454741" type="hidden" value="3T 10:00am - 11:00am Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454742">
# <input class="durc" data-seq="12622103" id="sch545454742" name="sid[]" onchange="checkDur('545454742');" type="checkbox" value="545454742"/>
# 						11:00am - 12:00pm
# 					  </label>
# </div><input id="sch545454742dur" name="dur545454742" type="hidden" value="60"/><input id="t_sch545454742" name="t_sch545454742" type="hidden" value="3T 11:00am - 12:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454743">
# <input class="durc" data-seq="12622104" id="sch545454743" name="sid[]" onchange="checkDur('545454743');" type="checkbox" value="545454743"/>
# 						12:00pm - 1:00pm
# 					  </label>
# </div><input id="sch545454743dur" name="dur545454743" type="hidden" value="60"/><input id="t_sch545454743" name="t_sch545454743" type="hidden" value="3T 12:00pm - 1:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454744">
# <input class="durc" data-seq="12622105" id="sch545454744" name="sid[]" onchange="checkDur('545454744');" type="checkbox" value="545454744"/>
# 						1:00pm - 2:00pm
# 					  </label>
# </div><input id="sch545454744dur" name="dur545454744" type="hidden" value="60"/><input id="t_sch545454744" name="t_sch545454744" type="hidden" value="3T 1:00pm - 2:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454745">
# <input class="durc" data-seq="12622106" id="sch545454745" name="sid[]" onchange="checkDur('545454745');" type="checkbox" value="545454745"/>
# 						2:00pm - 3:00pm
# 					  </label>
# </div><input id="sch545454745dur" name="dur545454745" type="hidden" value="60"/><input id="t_sch545454745" name="t_sch545454745" type="hidden" value="3T 2:00pm - 3:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454746">
# <input class="durc" data-seq="12622107" id="sch545454746" name="sid[]" onchange="checkDur('545454746');" type="checkbox" value="545454746"/>
# 						3:00pm - 4:00pm
# 					  </label>
# </div><input id="sch545454746dur" name="dur545454746" type="hidden" value="60"/><input id="t_sch545454746" name="t_sch545454746" type="hidden" value="3T 3:00pm - 4:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch548615141">
# <input class="durc" data-seq="12622108" id="sch548615141" name="sid[]" onchange="checkDur('548615141');" type="checkbox" value="548615141"/>
# 						4:00pm - 5:00pm
# 					  </label>
# </div><input id="sch548615141dur" name="dur548615141" type="hidden" value="60"/><input id="t_sch548615141" name="t_sch548615141" type="hidden" value="3T 4:00pm - 5:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch548615142">
# <input class="durc" data-seq="12622109" id="sch548615142" name="sid[]" onchange="checkDur('548615142');" type="checkbox" value="548615142"/>
# 						5:00pm - 6:00pm
# 					  </label>
# </div><input id="sch548615142dur" name="dur548615142" type="hidden" value="60"/><input id="t_sch548615142" name="t_sch548615142" type="hidden" value="3T 5:00pm - 6:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch548615143">
# <input class="durc" data-seq="12622110" id="sch548615143" name="sid[]" onchange="checkDur('548615143');" type="checkbox" value="548615143"/>
# 						6:00pm - 7:00pm
# 					  </label>
# </div><input id="sch548615143dur" name="dur548615143" type="hidden" value="60"/><input id="t_sch548615143" name="t_sch548615143" type="hidden" value="3T 6:00pm - 7:00pm Friday, July 21, 2017"/></fieldset><fieldset class="s-lc-rm-cap-l-1"><legend><h2>3U </h2></legend><div class="checkbox">
# <label for="sch545454733">
# <input class="durc" data-seq="12623101" id="sch545454733" name="sid[]" onchange="checkDur('545454733');" type="checkbox" value="545454733"/>
# 						9:00am - 10:00am
# 					  </label>
# </div><input id="sch545454733dur" name="dur545454733" type="hidden" value="60"/><input id="t_sch545454733" name="t_sch545454733" type="hidden" value="3U 9:00am - 10:00am Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454734">
# <input class="durc" data-seq="12623102" id="sch545454734" name="sid[]" onchange="checkDur('545454734');" type="checkbox" value="545454734"/>
# 						10:00am - 11:00am
# 					  </label>
# </div><input id="sch545454734dur" name="dur545454734" type="hidden" value="60"/><input id="t_sch545454734" name="t_sch545454734" type="hidden" value="3U 10:00am - 11:00am Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454735">
# <input class="durc" data-seq="12623103" id="sch545454735" name="sid[]" onchange="checkDur('545454735');" type="checkbox" value="545454735"/>
# 						11:00am - 12:00pm
# 					  </label>
# </div><input id="sch545454735dur" name="dur545454735" type="hidden" value="60"/><input id="t_sch545454735" name="t_sch545454735" type="hidden" value="3U 11:00am - 12:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454736">
# <input class="durc" data-seq="12623104" id="sch545454736" name="sid[]" onchange="checkDur('545454736');" type="checkbox" value="545454736"/>
# 						12:00pm - 1:00pm
# 					  </label>
# </div><input id="sch545454736dur" name="dur545454736" type="hidden" value="60"/><input id="t_sch545454736" name="t_sch545454736" type="hidden" value="3U 12:00pm - 1:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454737">
# <input class="durc" data-seq="12623105" id="sch545454737" name="sid[]" onchange="checkDur('545454737');" type="checkbox" value="545454737"/>
# 						1:00pm - 2:00pm
# 					  </label>
# </div><input id="sch545454737dur" name="dur545454737" type="hidden" value="60"/><input id="t_sch545454737" name="t_sch545454737" type="hidden" value="3U 1:00pm - 2:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454738">
# <input class="durc" data-seq="12623106" id="sch545454738" name="sid[]" onchange="checkDur('545454738');" type="checkbox" value="545454738"/>
# 						2:00pm - 3:00pm
# 					  </label>
# </div><input id="sch545454738dur" name="dur545454738" type="hidden" value="60"/><input id="t_sch545454738" name="t_sch545454738" type="hidden" value="3U 2:00pm - 3:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454739">
# <input class="durc" data-seq="12623107" id="sch545454739" name="sid[]" onchange="checkDur('545454739');" type="checkbox" value="545454739"/>
# 						3:00pm - 4:00pm
# 					  </label>
# </div><input id="sch545454739dur" name="dur545454739" type="hidden" value="60"/><input id="t_sch545454739" name="t_sch545454739" type="hidden" value="3U 3:00pm - 4:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch548615138">
# <input class="durc" data-seq="12623108" id="sch548615138" name="sid[]" onchange="checkDur('548615138');" type="checkbox" value="548615138"/>
# 						4:00pm - 5:00pm
# 					  </label>
# </div><input id="sch548615138dur" name="dur548615138" type="hidden" value="60"/><input id="t_sch548615138" name="t_sch548615138" type="hidden" value="3U 4:00pm - 5:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch548615139">
# <input class="durc" data-seq="12623109" id="sch548615139" name="sid[]" onchange="checkDur('548615139');" type="checkbox" value="548615139"/>
# 						5:00pm - 6:00pm
# 					  </label>
# </div><input id="sch548615139dur" name="dur548615139" type="hidden" value="60"/><input id="t_sch548615139" name="t_sch548615139" type="hidden" value="3U 5:00pm - 6:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch548615140">
# <input class="durc" data-seq="12623110" id="sch548615140" name="sid[]" onchange="checkDur('548615140');" type="checkbox" value="548615140"/>
# 						6:00pm - 7:00pm
# 					  </label>
# </div><input id="sch548615140dur" name="dur548615140" type="hidden" value="60"/><input id="t_sch548615140" name="t_sch548615140" type="hidden" value="3U 6:00pm - 7:00pm Friday, July 21, 2017"/></fieldset><fieldset class="s-lc-rm-cap-l-1"><legend><h2>3W </h2></legend><div class="checkbox">
# <label for="sch545454726">
# <input class="durc" data-seq="12624101" id="sch545454726" name="sid[]" onchange="checkDur('545454726');" type="checkbox" value="545454726"/>
# 						9:00am - 10:00am
# 					  </label>
# </div><input id="sch545454726dur" name="dur545454726" type="hidden" value="60"/><input id="t_sch545454726" name="t_sch545454726" type="hidden" value="3W 9:00am - 10:00am Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454727">
# <input class="durc" data-seq="12624102" id="sch545454727" name="sid[]" onchange="checkDur('545454727');" type="checkbox" value="545454727"/>
# 						10:00am - 11:00am
# 					  </label>
# </div><input id="sch545454727dur" name="dur545454727" type="hidden" value="60"/><input id="t_sch545454727" name="t_sch545454727" type="hidden" value="3W 10:00am - 11:00am Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454728">
# <input class="durc" data-seq="12624103" id="sch545454728" name="sid[]" onchange="checkDur('545454728');" type="checkbox" value="545454728"/>
# 						11:00am - 12:00pm
# 					  </label>
# </div><input id="sch545454728dur" name="dur545454728" type="hidden" value="60"/><input id="t_sch545454728" name="t_sch545454728" type="hidden" value="3W 11:00am - 12:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454729">
# <input class="durc" data-seq="12624104" id="sch545454729" name="sid[]" onchange="checkDur('545454729');" type="checkbox" value="545454729"/>
# 						12:00pm - 1:00pm
# 					  </label>
# </div><input id="sch545454729dur" name="dur545454729" type="hidden" value="60"/><input id="t_sch545454729" name="t_sch545454729" type="hidden" value="3W 12:00pm - 1:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454730">
# <input class="durc" data-seq="12624105" id="sch545454730" name="sid[]" onchange="checkDur('545454730');" type="checkbox" value="545454730"/>
# 						1:00pm - 2:00pm
# 					  </label>
# </div><input id="sch545454730dur" name="dur545454730" type="hidden" value="60"/><input id="t_sch545454730" name="t_sch545454730" type="hidden" value="3W 1:00pm - 2:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454731">
# <input class="durc" data-seq="12624106" id="sch545454731" name="sid[]" onchange="checkDur('545454731');" type="checkbox" value="545454731"/>
# 						2:00pm - 3:00pm
# 					  </label>
# </div><input id="sch545454731dur" name="dur545454731" type="hidden" value="60"/><input id="t_sch545454731" name="t_sch545454731" type="hidden" value="3W 2:00pm - 3:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454732">
# <input class="durc" data-seq="12624107" id="sch545454732" name="sid[]" onchange="checkDur('545454732');" type="checkbox" value="545454732"/>
# 						3:00pm - 4:00pm
# 					  </label>
# </div><input id="sch545454732dur" name="dur545454732" type="hidden" value="60"/><input id="t_sch545454732" name="t_sch545454732" type="hidden" value="3W 3:00pm - 4:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch548615135">
# <input class="durc" data-seq="12624108" id="sch548615135" name="sid[]" onchange="checkDur('548615135');" type="checkbox" value="548615135"/>
# 						4:00pm - 5:00pm
# 					  </label>
# </div><input id="sch548615135dur" name="dur548615135" type="hidden" value="60"/><input id="t_sch548615135" name="t_sch548615135" type="hidden" value="3W 4:00pm - 5:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch548615136">
# <input class="durc" data-seq="12624109" id="sch548615136" name="sid[]" onchange="checkDur('548615136');" type="checkbox" value="548615136"/>
# 						5:00pm - 6:00pm
# 					  </label>
# </div><input id="sch548615136dur" name="dur548615136" type="hidden" value="60"/><input id="t_sch548615136" name="t_sch548615136" type="hidden" value="3W 5:00pm - 6:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch548615137">
# <input class="durc" data-seq="12624110" id="sch548615137" name="sid[]" onchange="checkDur('548615137');" type="checkbox" value="548615137"/>
# 						6:00pm - 7:00pm
# 					  </label>
# </div><input id="sch548615137dur" name="dur548615137" type="hidden" value="60"/><input id="t_sch548615137" name="t_sch548615137" type="hidden" value="3W 6:00pm - 7:00pm Friday, July 21, 2017"/></fieldset><fieldset class="s-lc-rm-cap-l-1"><legend><h2>3X </h2></legend><div class="checkbox">
# <label for="sch545454719">
# <input class="durc" data-seq="12625101" id="sch545454719" name="sid[]" onchange="checkDur('545454719');" type="checkbox" value="545454719"/>
# 						9:00am - 10:00am
# 					  </label>
# </div><input id="sch545454719dur" name="dur545454719" type="hidden" value="60"/><input id="t_sch545454719" name="t_sch545454719" type="hidden" value="3X 9:00am - 10:00am Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454720">
# <input class="durc" data-seq="12625102" id="sch545454720" name="sid[]" onchange="checkDur('545454720');" type="checkbox" value="545454720"/>
# 						10:00am - 11:00am
# 					  </label>
# </div><input id="sch545454720dur" name="dur545454720" type="hidden" value="60"/><input id="t_sch545454720" name="t_sch545454720" type="hidden" value="3X 10:00am - 11:00am Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454721">
# <input class="durc" data-seq="12625103" id="sch545454721" name="sid[]" onchange="checkDur('545454721');" type="checkbox" value="545454721"/>
# 						11:00am - 12:00pm
# 					  </label>
# </div><input id="sch545454721dur" name="dur545454721" type="hidden" value="60"/><input id="t_sch545454721" name="t_sch545454721" type="hidden" value="3X 11:00am - 12:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454722">
# <input class="durc" data-seq="12625104" id="sch545454722" name="sid[]" onchange="checkDur('545454722');" type="checkbox" value="545454722"/>
# 						12:00pm - 1:00pm
# 					  </label>
# </div><input id="sch545454722dur" name="dur545454722" type="hidden" value="60"/><input id="t_sch545454722" name="t_sch545454722" type="hidden" value="3X 12:00pm - 1:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454723">
# <input class="durc" data-seq="12625105" id="sch545454723" name="sid[]" onchange="checkDur('545454723');" type="checkbox" value="545454723"/>
# 						1:00pm - 2:00pm
# 					  </label>
# </div><input id="sch545454723dur" name="dur545454723" type="hidden" value="60"/><input id="t_sch545454723" name="t_sch545454723" type="hidden" value="3X 1:00pm - 2:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454724">
# <input class="durc" data-seq="12625106" id="sch545454724" name="sid[]" onchange="checkDur('545454724');" type="checkbox" value="545454724"/>
# 						2:00pm - 3:00pm
# 					  </label>
# </div><input id="sch545454724dur" name="dur545454724" type="hidden" value="60"/><input id="t_sch545454724" name="t_sch545454724" type="hidden" value="3X 2:00pm - 3:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454725">
# <input class="durc" data-seq="12625107" id="sch545454725" name="sid[]" onchange="checkDur('545454725');" type="checkbox" value="545454725"/>
# 						3:00pm - 4:00pm
# 					  </label>
# </div><input id="sch545454725dur" name="dur545454725" type="hidden" value="60"/><input id="t_sch545454725" name="t_sch545454725" type="hidden" value="3X 3:00pm - 4:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch548615132">
# <input class="durc" data-seq="12625108" id="sch548615132" name="sid[]" onchange="checkDur('548615132');" type="checkbox" value="548615132"/>
# 						4:00pm - 5:00pm
# 					  </label>
# </div><input id="sch548615132dur" name="dur548615132" type="hidden" value="60"/><input id="t_sch548615132" name="t_sch548615132" type="hidden" value="3X 4:00pm - 5:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch548615133">
# <input class="durc" data-seq="12625109" id="sch548615133" name="sid[]" onchange="checkDur('548615133');" type="checkbox" value="548615133"/>
# 						5:00pm - 6:00pm
# 					  </label>
# </div><input id="sch548615133dur" name="dur548615133" type="hidden" value="60"/><input id="t_sch548615133" name="t_sch548615133" type="hidden" value="3X 5:00pm - 6:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch548615134">
# <input class="durc" data-seq="12625110" id="sch548615134" name="sid[]" onchange="checkDur('548615134');" type="checkbox" value="548615134"/>
# 						6:00pm - 7:00pm
# 					  </label>
# </div><input id="sch548615134dur" name="dur548615134" type="hidden" value="60"/><input id="t_sch548615134" name="t_sch548615134" type="hidden" value="3X 6:00pm - 7:00pm Friday, July 21, 2017"/></fieldset><fieldset class="s-lc-rm-cap-l-1"><legend><h2>3AA </h2></legend><div class="checkbox">
# <label for="sch545454824">
# <input class="durc" data-seq="12627101" id="sch545454824" name="sid[]" onchange="checkDur('545454824');" type="checkbox" value="545454824"/>
# 						9:00am - 10:00am
# 					  </label>
# </div><input id="sch545454824dur" name="dur545454824" type="hidden" value="60"/><input id="t_sch545454824" name="t_sch545454824" type="hidden" value="3AA 9:00am - 10:00am Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454825">
# <input class="durc" data-seq="12627102" id="sch545454825" name="sid[]" onchange="checkDur('545454825');" type="checkbox" value="545454825"/>
# 						10:00am - 11:00am
# 					  </label>
# </div><input id="sch545454825dur" name="dur545454825" type="hidden" value="60"/><input id="t_sch545454825" name="t_sch545454825" type="hidden" value="3AA 10:00am - 11:00am Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454826">
# <input class="durc" data-seq="12627103" id="sch545454826" name="sid[]" onchange="checkDur('545454826');" type="checkbox" value="545454826"/>
# 						11:00am - 12:00pm
# 					  </label>
# </div><input id="sch545454826dur" name="dur545454826" type="hidden" value="60"/><input id="t_sch545454826" name="t_sch545454826" type="hidden" value="3AA 11:00am - 12:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454827">
# <input class="durc" data-seq="12627104" id="sch545454827" name="sid[]" onchange="checkDur('545454827');" type="checkbox" value="545454827"/>
# 						12:00pm - 1:00pm
# 					  </label>
# </div><input id="sch545454827dur" name="dur545454827" type="hidden" value="60"/><input id="t_sch545454827" name="t_sch545454827" type="hidden" value="3AA 12:00pm - 1:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454828">
# <input class="durc" data-seq="12627105" id="sch545454828" name="sid[]" onchange="checkDur('545454828');" type="checkbox" value="545454828"/>
# 						1:00pm - 2:00pm
# 					  </label>
# </div><input id="sch545454828dur" name="dur545454828" type="hidden" value="60"/><input id="t_sch545454828" name="t_sch545454828" type="hidden" value="3AA 1:00pm - 2:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454829">
# <input class="durc" data-seq="12627106" id="sch545454829" name="sid[]" onchange="checkDur('545454829');" type="checkbox" value="545454829"/>
# 						2:00pm - 3:00pm
# 					  </label>
# </div><input id="sch545454829dur" name="dur545454829" type="hidden" value="60"/><input id="t_sch545454829" name="t_sch545454829" type="hidden" value="3AA 2:00pm - 3:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454830">
# <input class="durc" data-seq="12627107" id="sch545454830" name="sid[]" onchange="checkDur('545454830');" type="checkbox" value="545454830"/>
# 						3:00pm - 4:00pm
# 					  </label>
# </div><input id="sch545454830dur" name="dur545454830" type="hidden" value="60"/><input id="t_sch545454830" name="t_sch545454830" type="hidden" value="3AA 3:00pm - 4:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch548615177">
# <input class="durc" data-seq="12627108" id="sch548615177" name="sid[]" onchange="checkDur('548615177');" type="checkbox" value="548615177"/>
# 						4:00pm - 5:00pm
# 					  </label>
# </div><input id="sch548615177dur" name="dur548615177" type="hidden" value="60"/><input id="t_sch548615177" name="t_sch548615177" type="hidden" value="3AA 4:00pm - 5:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch548615178">
# <input class="durc" data-seq="12627109" id="sch548615178" name="sid[]" onchange="checkDur('548615178');" type="checkbox" value="548615178"/>
# 						5:00pm - 6:00pm
# 					  </label>
# </div><input id="sch548615178dur" name="dur548615178" type="hidden" value="60"/><input id="t_sch548615178" name="t_sch548615178" type="hidden" value="3AA 5:00pm - 6:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch548615179">
# <input class="durc" data-seq="12627110" id="sch548615179" name="sid[]" onchange="checkDur('548615179');" type="checkbox" value="548615179"/>
# 						6:00pm - 7:00pm
# 					  </label>
# </div><input id="sch548615179dur" name="dur548615179" type="hidden" value="60"/><input id="t_sch548615179" name="t_sch548615179" type="hidden" value="3AA 6:00pm - 7:00pm Friday, July 21, 2017"/></fieldset><fieldset class="s-lc-rm-cap-l-1"><legend><h2>3K </h2></legend><div class="checkbox">
# <label for="sch545454712">
# <input class="durc" data-seq="12446101" id="sch545454712" name="sid[]" onchange="checkDur('545454712');" type="checkbox" value="545454712"/>
# 						9:00am - 10:00am
# 					  </label>
# </div><input id="sch545454712dur" name="dur545454712" type="hidden" value="60"/><input id="t_sch545454712" name="t_sch545454712" type="hidden" value="3K 9:00am - 10:00am Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454713">
# <input class="durc" data-seq="12446102" id="sch545454713" name="sid[]" onchange="checkDur('545454713');" type="checkbox" value="545454713"/>
# 						10:00am - 11:00am
# 					  </label>
# </div><input id="sch545454713dur" name="dur545454713" type="hidden" value="60"/><input id="t_sch545454713" name="t_sch545454713" type="hidden" value="3K 10:00am - 11:00am Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454714">
# <input class="durc" data-seq="12446103" id="sch545454714" name="sid[]" onchange="checkDur('545454714');" type="checkbox" value="545454714"/>
# 						11:00am - 12:00pm
# 					  </label>
# </div><input id="sch545454714dur" name="dur545454714" type="hidden" value="60"/><input id="t_sch545454714" name="t_sch545454714" type="hidden" value="3K 11:00am - 12:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch548615131">
# <input class="durc" data-seq="12446110" id="sch548615131" name="sid[]" onchange="checkDur('548615131');" type="checkbox" value="548615131"/>
# 						6:00pm - 7:00pm
# 					  </label>
# </div><input id="sch548615131dur" name="dur548615131" type="hidden" value="60"/><input id="t_sch548615131" name="t_sch548615131" type="hidden" value="3K 6:00pm - 7:00pm Friday, July 21, 2017"/></fieldset><fieldset class="s-lc-rm-cap-l-1"><legend><h2>3L </h2></legend><div class="checkbox">
# <label for="sch545454817">
# <input class="durc" data-seq="12447101" id="sch545454817" name="sid[]" onchange="checkDur('545454817');" type="checkbox" value="545454817"/>
# 						9:00am - 10:00am
# 					  </label>
# </div><input id="sch545454817dur" name="dur545454817" type="hidden" value="60"/><input id="t_sch545454817" name="t_sch545454817" type="hidden" value="3L 9:00am - 10:00am Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454818">
# <input class="durc" data-seq="12447102" id="sch545454818" name="sid[]" onchange="checkDur('545454818');" type="checkbox" value="545454818"/>
# 						10:00am - 11:00am
# 					  </label>
# </div><input id="sch545454818dur" name="dur545454818" type="hidden" value="60"/><input id="t_sch545454818" name="t_sch545454818" type="hidden" value="3L 10:00am - 11:00am Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454819">
# <input class="durc" data-seq="12447103" id="sch545454819" name="sid[]" onchange="checkDur('545454819');" type="checkbox" value="545454819"/>
# 						11:00am - 12:00pm
# 					  </label>
# </div><input id="sch545454819dur" name="dur545454819" type="hidden" value="60"/><input id="t_sch545454819" name="t_sch545454819" type="hidden" value="3L 11:00am - 12:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454820">
# <input class="durc" data-seq="12447104" id="sch545454820" name="sid[]" onchange="checkDur('545454820');" type="checkbox" value="545454820"/>
# 						12:00pm - 1:00pm
# 					  </label>
# </div><input id="sch545454820dur" name="dur545454820" type="hidden" value="60"/><input id="t_sch545454820" name="t_sch545454820" type="hidden" value="3L 12:00pm - 1:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454821">
# <input class="durc" data-seq="12447105" id="sch545454821" name="sid[]" onchange="checkDur('545454821');" type="checkbox" value="545454821"/>
# 						1:00pm - 2:00pm
# 					  </label>
# </div><input id="sch545454821dur" name="dur545454821" type="hidden" value="60"/><input id="t_sch545454821" name="t_sch545454821" type="hidden" value="3L 1:00pm - 2:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454822">
# <input class="durc" data-seq="12447106" id="sch545454822" name="sid[]" onchange="checkDur('545454822');" type="checkbox" value="545454822"/>
# 						2:00pm - 3:00pm
# 					  </label>
# </div><input id="sch545454822dur" name="dur545454822" type="hidden" value="60"/><input id="t_sch545454822" name="t_sch545454822" type="hidden" value="3L 2:00pm - 3:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454823">
# <input class="durc" data-seq="12447107" id="sch545454823" name="sid[]" onchange="checkDur('545454823');" type="checkbox" value="545454823"/>
# 						3:00pm - 4:00pm
# 					  </label>
# </div><input id="sch545454823dur" name="dur545454823" type="hidden" value="60"/><input id="t_sch545454823" name="t_sch545454823" type="hidden" value="3L 3:00pm - 4:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch548615174">
# <input class="durc" data-seq="12447108" id="sch548615174" name="sid[]" onchange="checkDur('548615174');" type="checkbox" value="548615174"/>
# 						4:00pm - 5:00pm
# 					  </label>
# </div><input id="sch548615174dur" name="dur548615174" type="hidden" value="60"/><input id="t_sch548615174" name="t_sch548615174" type="hidden" value="3L 4:00pm - 5:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch548615175">
# <input class="durc" data-seq="12447109" id="sch548615175" name="sid[]" onchange="checkDur('548615175');" type="checkbox" value="548615175"/>
# 						5:00pm - 6:00pm
# 					  </label>
# </div><input id="sch548615175dur" name="dur548615175" type="hidden" value="60"/><input id="t_sch548615175" name="t_sch548615175" type="hidden" value="3L 5:00pm - 6:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch548615176">
# <input class="durc" data-seq="12447110" id="sch548615176" name="sid[]" onchange="checkDur('548615176');" type="checkbox" value="548615176"/>
# 						6:00pm - 7:00pm
# 					  </label>
# </div><input id="sch548615176dur" name="dur548615176" type="hidden" value="60"/><input id="t_sch548615176" name="t_sch548615176" type="hidden" value="3L 6:00pm - 7:00pm Friday, July 21, 2017"/></fieldset><fieldset class="s-lc-rm-cap-l-1"><legend><h2>3N </h2></legend><div class="checkbox">
# <label for="sch545454803">
# <input class="durc" data-seq="12449101" id="sch545454803" name="sid[]" onchange="checkDur('545454803');" type="checkbox" value="545454803"/>
# 						9:00am - 10:00am
# 					  </label>
# </div><input id="sch545454803dur" name="dur545454803" type="hidden" value="60"/><input id="t_sch545454803" name="t_sch545454803" type="hidden" value="3N 9:00am - 10:00am Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454804">
# <input class="durc" data-seq="12449102" id="sch545454804" name="sid[]" onchange="checkDur('545454804');" type="checkbox" value="545454804"/>
# 						10:00am - 11:00am
# 					  </label>
# </div><input id="sch545454804dur" name="dur545454804" type="hidden" value="60"/><input id="t_sch545454804" name="t_sch545454804" type="hidden" value="3N 10:00am - 11:00am Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454805">
# <input class="durc" data-seq="12449103" id="sch545454805" name="sid[]" onchange="checkDur('545454805');" type="checkbox" value="545454805"/>
# 						11:00am - 12:00pm
# 					  </label>
# </div><input id="sch545454805dur" name="dur545454805" type="hidden" value="60"/><input id="t_sch545454805" name="t_sch545454805" type="hidden" value="3N 11:00am - 12:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454806">
# <input class="durc" data-seq="12449104" id="sch545454806" name="sid[]" onchange="checkDur('545454806');" type="checkbox" value="545454806"/>
# 						12:00pm - 1:00pm
# 					  </label>
# </div><input id="sch545454806dur" name="dur545454806" type="hidden" value="60"/><input id="t_sch545454806" name="t_sch545454806" type="hidden" value="3N 12:00pm - 1:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454807">
# <input class="durc" data-seq="12449105" id="sch545454807" name="sid[]" onchange="checkDur('545454807');" type="checkbox" value="545454807"/>
# 						1:00pm - 2:00pm
# 					  </label>
# </div><input id="sch545454807dur" name="dur545454807" type="hidden" value="60"/><input id="t_sch545454807" name="t_sch545454807" type="hidden" value="3N 1:00pm - 2:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454808">
# <input class="durc" data-seq="12449106" id="sch545454808" name="sid[]" onchange="checkDur('545454808');" type="checkbox" value="545454808"/>
# 						2:00pm - 3:00pm
# 					  </label>
# </div><input id="sch545454808dur" name="dur545454808" type="hidden" value="60"/><input id="t_sch545454808" name="t_sch545454808" type="hidden" value="3N 2:00pm - 3:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454809">
# <input class="durc" data-seq="12449107" id="sch545454809" name="sid[]" onchange="checkDur('545454809');" type="checkbox" value="545454809"/>
# 						3:00pm - 4:00pm
# 					  </label>
# </div><input id="sch545454809dur" name="dur545454809" type="hidden" value="60"/><input id="t_sch545454809" name="t_sch545454809" type="hidden" value="3N 3:00pm - 4:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch548615168">
# <input class="durc" data-seq="12449108" id="sch548615168" name="sid[]" onchange="checkDur('548615168');" type="checkbox" value="548615168"/>
# 						4:00pm - 5:00pm
# 					  </label>
# </div><input id="sch548615168dur" name="dur548615168" type="hidden" value="60"/><input id="t_sch548615168" name="t_sch548615168" type="hidden" value="3N 4:00pm - 5:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch548615169">
# <input class="durc" data-seq="12449109" id="sch548615169" name="sid[]" onchange="checkDur('548615169');" type="checkbox" value="548615169"/>
# 						5:00pm - 6:00pm
# 					  </label>
# </div><input id="sch548615169dur" name="dur548615169" type="hidden" value="60"/><input id="t_sch548615169" name="t_sch548615169" type="hidden" value="3N 5:00pm - 6:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch548615170">
# <input class="durc" data-seq="12449110" id="sch548615170" name="sid[]" onchange="checkDur('548615170');" type="checkbox" value="548615170"/>
# 						6:00pm - 7:00pm
# 					  </label>
# </div><input id="sch548615170dur" name="dur548615170" type="hidden" value="60"/><input id="t_sch548615170" name="t_sch548615170" type="hidden" value="3N 6:00pm - 7:00pm Friday, July 21, 2017"/></fieldset><fieldset class="s-lc-rm-cap-l-1"><legend><h2>3P </h2></legend><div class="checkbox">
# <label for="sch545454796">
# <input class="durc" data-seq="12450101" id="sch545454796" name="sid[]" onchange="checkDur('545454796');" type="checkbox" value="545454796"/>
# 						9:00am - 10:00am
# 					  </label>
# </div><input id="sch545454796dur" name="dur545454796" type="hidden" value="60"/><input id="t_sch545454796" name="t_sch545454796" type="hidden" value="3P 9:00am - 10:00am Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454797">
# <input class="durc" data-seq="12450102" id="sch545454797" name="sid[]" onchange="checkDur('545454797');" type="checkbox" value="545454797"/>
# 						10:00am - 11:00am
# 					  </label>
# </div><input id="sch545454797dur" name="dur545454797" type="hidden" value="60"/><input id="t_sch545454797" name="t_sch545454797" type="hidden" value="3P 10:00am - 11:00am Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454798">
# <input class="durc" data-seq="12450103" id="sch545454798" name="sid[]" onchange="checkDur('545454798');" type="checkbox" value="545454798"/>
# 						11:00am - 12:00pm
# 					  </label>
# </div><input id="sch545454798dur" name="dur545454798" type="hidden" value="60"/><input id="t_sch545454798" name="t_sch545454798" type="hidden" value="3P 11:00am - 12:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454799">
# <input class="durc" data-seq="12450104" id="sch545454799" name="sid[]" onchange="checkDur('545454799');" type="checkbox" value="545454799"/>
# 						12:00pm - 1:00pm
# 					  </label>
# </div><input id="sch545454799dur" name="dur545454799" type="hidden" value="60"/><input id="t_sch545454799" name="t_sch545454799" type="hidden" value="3P 12:00pm - 1:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454800">
# <input class="durc" data-seq="12450105" id="sch545454800" name="sid[]" onchange="checkDur('545454800');" type="checkbox" value="545454800"/>
# 						1:00pm - 2:00pm
# 					  </label>
# </div><input id="sch545454800dur" name="dur545454800" type="hidden" value="60"/><input id="t_sch545454800" name="t_sch545454800" type="hidden" value="3P 1:00pm - 2:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454801">
# <input class="durc" data-seq="12450106" id="sch545454801" name="sid[]" onchange="checkDur('545454801');" type="checkbox" value="545454801"/>
# 						2:00pm - 3:00pm
# 					  </label>
# </div><input id="sch545454801dur" name="dur545454801" type="hidden" value="60"/><input id="t_sch545454801" name="t_sch545454801" type="hidden" value="3P 2:00pm - 3:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454802">
# <input class="durc" data-seq="12450107" id="sch545454802" name="sid[]" onchange="checkDur('545454802');" type="checkbox" value="545454802"/>
# 						3:00pm - 4:00pm
# 					  </label>
# </div><input id="sch545454802dur" name="dur545454802" type="hidden" value="60"/><input id="t_sch545454802" name="t_sch545454802" type="hidden" value="3P 3:00pm - 4:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch548615165">
# <input class="durc" data-seq="12450108" id="sch548615165" name="sid[]" onchange="checkDur('548615165');" type="checkbox" value="548615165"/>
# 						4:00pm - 5:00pm
# 					  </label>
# </div><input id="sch548615165dur" name="dur548615165" type="hidden" value="60"/><input id="t_sch548615165" name="t_sch548615165" type="hidden" value="3P 4:00pm - 5:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch548615166">
# <input class="durc" data-seq="12450109" id="sch548615166" name="sid[]" onchange="checkDur('548615166');" type="checkbox" value="548615166"/>
# 						5:00pm - 6:00pm
# 					  </label>
# </div><input id="sch548615166dur" name="dur548615166" type="hidden" value="60"/><input id="t_sch548615166" name="t_sch548615166" type="hidden" value="3P 5:00pm - 6:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch548615167">
# <input class="durc" data-seq="12450110" id="sch548615167" name="sid[]" onchange="checkDur('548615167');" type="checkbox" value="548615167"/>
# 						6:00pm - 7:00pm
# 					  </label>
# </div><input id="sch548615167dur" name="dur548615167" type="hidden" value="60"/><input id="t_sch548615167" name="t_sch548615167" type="hidden" value="3P 6:00pm - 7:00pm Friday, July 21, 2017"/></fieldset><fieldset class="s-lc-rm-cap-l-1"><legend><h2>3Q </h2></legend><div class="checkbox">
# <label for="sch545454789">
# <input class="durc" data-seq="12451101" id="sch545454789" name="sid[]" onchange="checkDur('545454789');" type="checkbox" value="545454789"/>
# 						9:00am - 10:00am
# 					  </label>
# </div><input id="sch545454789dur" name="dur545454789" type="hidden" value="60"/><input id="t_sch545454789" name="t_sch545454789" type="hidden" value="3Q 9:00am - 10:00am Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454790">
# <input class="durc" data-seq="12451102" id="sch545454790" name="sid[]" onchange="checkDur('545454790');" type="checkbox" value="545454790"/>
# 						10:00am - 11:00am
# 					  </label>
# </div><input id="sch545454790dur" name="dur545454790" type="hidden" value="60"/><input id="t_sch545454790" name="t_sch545454790" type="hidden" value="3Q 10:00am - 11:00am Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454791">
# <input class="durc" data-seq="12451103" id="sch545454791" name="sid[]" onchange="checkDur('545454791');" type="checkbox" value="545454791"/>
# 						11:00am - 12:00pm
# 					  </label>
# </div><input id="sch545454791dur" name="dur545454791" type="hidden" value="60"/><input id="t_sch545454791" name="t_sch545454791" type="hidden" value="3Q 11:00am - 12:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454792">
# <input class="durc" data-seq="12451104" id="sch545454792" name="sid[]" onchange="checkDur('545454792');" type="checkbox" value="545454792"/>
# 						12:00pm - 1:00pm
# 					  </label>
# </div><input id="sch545454792dur" name="dur545454792" type="hidden" value="60"/><input id="t_sch545454792" name="t_sch545454792" type="hidden" value="3Q 12:00pm - 1:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454793">
# <input class="durc" data-seq="12451105" id="sch545454793" name="sid[]" onchange="checkDur('545454793');" type="checkbox" value="545454793"/>
# 						1:00pm - 2:00pm
# 					  </label>
# </div><input id="sch545454793dur" name="dur545454793" type="hidden" value="60"/><input id="t_sch545454793" name="t_sch545454793" type="hidden" value="3Q 1:00pm - 2:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454794">
# <input class="durc" data-seq="12451106" id="sch545454794" name="sid[]" onchange="checkDur('545454794');" type="checkbox" value="545454794"/>
# 						2:00pm - 3:00pm
# 					  </label>
# </div><input id="sch545454794dur" name="dur545454794" type="hidden" value="60"/><input id="t_sch545454794" name="t_sch545454794" type="hidden" value="3Q 2:00pm - 3:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch545454795">
# <input class="durc" data-seq="12451107" id="sch545454795" name="sid[]" onchange="checkDur('545454795');" type="checkbox" value="545454795"/>
# 						3:00pm - 4:00pm
# 					  </label>
# </div><input id="sch545454795dur" name="dur545454795" type="hidden" value="60"/><input id="t_sch545454795" name="t_sch545454795" type="hidden" value="3Q 3:00pm - 4:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch548615162">
# <input class="durc" data-seq="12451108" id="sch548615162" name="sid[]" onchange="checkDur('548615162');" type="checkbox" value="548615162"/>
# 						4:00pm - 5:00pm
# 					  </label>
# </div><input id="sch548615162dur" name="dur548615162" type="hidden" value="60"/><input id="t_sch548615162" name="t_sch548615162" type="hidden" value="3Q 4:00pm - 5:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch548615163">
# <input class="durc" data-seq="12451109" id="sch548615163" name="sid[]" onchange="checkDur('548615163');" type="checkbox" value="548615163"/>
# 						5:00pm - 6:00pm
# 					  </label>
# </div><input id="sch548615163dur" name="dur548615163" type="hidden" value="60"/><input id="t_sch548615163" name="t_sch548615163" type="hidden" value="3Q 5:00pm - 6:00pm Friday, July 21, 2017"/><div class="checkbox">
# <label for="sch548615164">
# <input class="durc" data-seq="12451110" id="sch548615164" name="sid[]" onchange="checkDur('548615164');" type="checkbox" value="548615164"/>
# 						6:00pm - 7:00pm
# 					  </label>
# </div><input id="sch548615164dur" name="dur548615164" type="hidden" value="60"/><input id="t_sch548615164" name="t_sch548615164" type="hidden" value="3Q 6:00pm - 7:00pm Friday, July 21, 2017"/></fieldset>
# </form>

# %%
import re
for i in book_room_form.stripped_strings:
#     pattern = re.compile('.*?3[A-Z]+.*?')
#     if pattern.search(i):
#         print(i)
    print(i)
# Out:
# 3F
# 9:00am - 10:00am
# 10:00am - 11:00am
# 11:00am - 12:00pm
# 1:00pm - 2:00pm
# 2:00pm - 3:00pm
# 3:00pm - 4:00pm
# 4:00pm - 5:00pm
# 5:00pm - 6:00pm
# 6:00pm - 7:00pm
# 3G
# 9:00am - 10:00am
# 10:00am - 11:00am
# 11:00am - 12:00pm
# 12:00pm - 1:00pm
# 1:00pm - 2:00pm
# 2:00pm - 3:00pm
# 3:00pm - 4:00pm
# 4:00pm - 5:00pm
# 5:00pm - 6:00pm
# 6:00pm - 7:00pm
# 3H
# 9:00am - 10:00am
# 10:00am - 11:00am
# 11:00am - 12:00pm
# 12:00pm - 1:00pm
# 1:00pm - 2:00pm
# 2:00pm - 3:00pm
# 3:00pm - 4:00pm
# 4:00pm - 5:00pm
# 5:00pm - 6:00pm
# 6:00pm - 7:00pm
# 3J
# 9:00am - 10:00am
# 10:00am - 11:00am
# 11:00am - 12:00pm
# 12:00pm - 1:00pm
# 1:00pm - 2:00pm
# 2:00pm - 3:00pm
# 3:00pm - 4:00pm
# 4:00pm - 5:00pm
# 5:00pm - 6:00pm
# 6:00pm - 7:00pm
# 3R
# 9:00am - 10:00am
# 10:00am - 11:00am
# 11:00am - 12:00pm
# 12:00pm - 1:00pm
# 1:00pm - 2:00pm
# 2:00pm - 3:00pm
# 3:00pm - 4:00pm
# 4:00pm - 5:00pm
# 5:00pm - 6:00pm
# 6:00pm - 7:00pm
# 3S
# 9:00am - 10:00am
# 10:00am - 11:00am
# 11:00am - 12:00pm
# 12:00pm - 1:00pm
# 1:00pm - 2:00pm
# 2:00pm - 3:00pm
# 3:00pm - 4:00pm
# 4:00pm - 5:00pm
# 5:00pm - 6:00pm
# 6:00pm - 7:00pm
# 3T
# 9:00am - 10:00am
# 10:00am - 11:00am
# 11:00am - 12:00pm
# 12:00pm - 1:00pm
# 1:00pm - 2:00pm
# 2:00pm - 3:00pm
# 3:00pm - 4:00pm
# 4:00pm - 5:00pm
# 5:00pm - 6:00pm
# 6:00pm - 7:00pm
# 3U
# 9:00am - 10:00am
# 10:00am - 11:00am
# 11:00am - 12:00pm
# 12:00pm - 1:00pm
# 1:00pm - 2:00pm
# 2:00pm - 3:00pm
# 3:00pm - 4:00pm
# 4:00pm - 5:00pm
# 5:00pm - 6:00pm
# 6:00pm - 7:00pm
# 3W
# 9:00am - 10:00am
# 10:00am - 11:00am
# 11:00am - 12:00pm
# 12:00pm - 1:00pm
# 1:00pm - 2:00pm
# 2:00pm - 3:00pm
# 3:00pm - 4:00pm
# 4:00pm - 5:00pm
# 5:00pm - 6:00pm
# 6:00pm - 7:00pm
# 3X
# 9:00am - 10:00am
# 10:00am - 11:00am
# 11:00am - 12:00pm
# 12:00pm - 1:00pm
# 1:00pm - 2:00pm
# 2:00pm - 3:00pm
# 3:00pm - 4:00pm
# 4:00pm - 5:00pm
# 5:00pm - 6:00pm
# 6:00pm - 7:00pm
# 3AA
# 9:00am - 10:00am
# 10:00am - 11:00am
# 11:00am - 12:00pm
# 12:00pm - 1:00pm
# 1:00pm - 2:00pm
# 2:00pm - 3:00pm
# 3:00pm - 4:00pm
# 4:00pm - 5:00pm
# 5:00pm - 6:00pm
# 6:00pm - 7:00pm
# 3K
# 9:00am - 10:00am
# 10:00am - 11:00am
# 11:00am - 12:00pm
# 12:00pm - 1:00pm
# 1:00pm - 2:00pm
# 2:00pm - 3:00pm
# 3:00pm - 4:00pm
# 4:00pm - 5:00pm
# 5:00pm - 6:00pm
# 6:00pm - 7:00pm
# 3L
# 9:00am - 10:00am
# 10:00am - 11:00am
# 11:00am - 12:00pm
# 12:00pm - 1:00pm
# 1:00pm - 2:00pm
# 2:00pm - 3:00pm
# 3:00pm - 4:00pm
# 4:00pm - 5:00pm
# 5:00pm - 6:00pm
# 6:00pm - 7:00pm
# 3N
# 9:00am - 10:00am
# 10:00am - 11:00am
# 11:00am - 12:00pm
# 12:00pm - 1:00pm
# 1:00pm - 2:00pm
# 2:00pm - 3:00pm
# 3:00pm - 4:00pm
# 4:00pm - 5:00pm
# 5:00pm - 6:00pm
# 6:00pm - 7:00pm
# 3P
# 9:00am - 10:00am
# 10:00am - 11:00am
# 11:00am - 12:00pm
# 12:00pm - 1:00pm
# 1:00pm - 2:00pm
# 2:00pm - 3:00pm
# 3:00pm - 4:00pm
# 4:00pm - 5:00pm
# 5:00pm - 6:00pm
# 6:00pm - 7:00pm
# 3Q
# 9:00am - 10:00am
# 10:00am - 11:00am
# 11:00am - 12:00pm
# 12:00pm - 1:00pm
# 1:00pm - 2:00pm
# 2:00pm - 3:00pm
# 3:00pm - 4:00pm
# 4:00pm - 5:00pm
# 5:00pm - 6:00pm
# 6:00pm - 7:00pm

# %%
flag = False
pattern = re.compile('[0-9]+:[0-9][0-9][a|p]m\s-\s[0-9]+:[0-9][0-9][a|p]m')
pattern2 = re.compile('.*?3[A-Z]+.*?')
for i in book_room_form.stripped_strings:
    if pattern2.search(i):
        flag = False
    if '3G' in i and flag==False:
        flag = True
    if flag and pattern.match(i):
        print(i)
# Out:
# 9:00am - 10:00am
# 10:00am - 11:00am
# 11:00am - 12:00pm
# 12:00pm - 1:00pm
# 1:00pm - 2:00pm
# 2:00pm - 3:00pm
# 3:00pm - 4:00pm
# 4:00pm - 5:00pm
# 5:00pm - 6:00pm
# 6:00pm - 7:00pm

# %%
text = book_room_form.get_text()

# %%
lines = (line.strip() for line in text.splitlines())
# break multi-headlines into a line each
chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
# drop blank lines
text = '\n'.join(chunk for chunk in chunks if chunk)

print(text)
# Out:
# 3F Capacity: 1Group Study Room
# 11:00am - 12:00pm
# 12:00pm - 1:00pm
# 1:00pm - 2:00pm
# 6:00pm - 7:00pm
# Skip to registration form3G Capacity: 1Group Study Room
# 9:00am - 10:00am
# 10:00am - 11:00am
# 11:00am - 12:00pm
# 12:00pm - 1:00pm
# 1:00pm - 2:00pm
# 4:00pm - 5:00pm
# 5:00pm - 6:00pm
# 6:00pm - 7:00pm
# Skip to registration form3H Capacity: 1Group Study Room
# 9:00am - 10:00am
# 10:00am - 11:00am
# 11:00am - 12:00pm
# 12:00pm - 1:00pm
# 3:00pm - 4:00pm
# 4:00pm - 5:00pm
# 5:00pm - 6:00pm
# 6:00pm - 7:00pm
# Skip to registration form3J Capacity: 1Group Study Room. Knoll furniture evaluation.
# 9:00am - 10:00am
# 10:00am - 11:00am
# 11:00am - 12:00pm
# 12:00pm - 1:00pm
# 1:00pm - 2:00pm
# 2:00pm - 3:00pm
# 3:00pm - 4:00pm
# 4:00pm - 5:00pm
# 5:00pm - 6:00pm
# 6:00pm - 7:00pm
# Skip to registration form3R Capacity: 1Group Study Room
# 9:00am - 10:00am
# 10:00am - 11:00am
# 11:00am - 12:00pm
# 12:00pm - 1:00pm
# 1:00pm - 2:00pm
# 2:00pm - 3:00pm
# 3:00pm - 4:00pm
# 4:00pm - 5:00pm
# 5:00pm - 6:00pm
# 6:00pm - 7:00pm
# Skip to registration form3S Capacity: 1Group Study Room
# 9:00am - 10:00am
# 10:00am - 11:00am
# 11:00am - 12:00pm
# 12:00pm - 1:00pm
# 1:00pm - 2:00pm
# 2:00pm - 3:00pm
# 3:00pm - 4:00pm
# 4:00pm - 5:00pm
# 5:00pm - 6:00pm
# 6:00pm - 7:00pm
# Skip to registration form3T Capacity: 1Group Study Room
# 9:00am - 10:00am
# 10:00am - 11:00am
# 11:00am - 12:00pm
# 12:00pm - 1:00pm
# 1:00pm - 2:00pm
# 2:00pm - 3:00pm
# 3:00pm - 4:00pm
# 4:00pm - 5:00pm
# 5:00pm - 6:00pm
# 6:00pm - 7:00pm
# Skip to registration form3U Capacity: 1Group Study Room
# 9:00am - 10:00am
# 10:00am - 11:00am
# 11:00am - 12:00pm
# 12:00pm - 1:00pm
# 1:00pm - 2:00pm
# 2:00pm - 3:00pm
# 3:00pm - 4:00pm
# 4:00pm - 5:00pm
# 5:00pm - 6:00pm
# 6:00pm - 7:00pm
# Skip to registration form3W Capacity: 1Group Study Room
# 9:00am - 10:00am
# 10:00am - 11:00am
# 11:00am - 12:00pm
# 12:00pm - 1:00pm
# 1:00pm - 2:00pm
# 2:00pm - 3:00pm
# 3:00pm - 4:00pm
# 4:00pm - 5:00pm
# 5:00pm - 6:00pm
# 6:00pm - 7:00pm
# Skip to registration form3X Capacity: 1Group Study Room
# 9:00am - 10:00am
# 10:00am - 11:00am
# 11:00am - 12:00pm
# 12:00pm - 1:00pm
# 1:00pm - 2:00pm
# 2:00pm - 3:00pm
# 3:00pm - 4:00pm
# 4:00pm - 5:00pm
# 5:00pm - 6:00pm
# 6:00pm - 7:00pm
# Skip to registration form3AA Capacity: 1Group Study Room
# 9:00am - 10:00am
# 10:00am - 11:00am
# 11:00am - 12:00pm
# 12:00pm - 1:00pm
# 1:00pm - 2:00pm
# 2:00pm - 3:00pm
# 3:00pm - 4:00pm
# 4:00pm - 5:00pm
# 5:00pm - 6:00pm
# 6:00pm - 7:00pm
# Skip to registration form3K Capacity: 1Group Study Room. Haworth technology and furniture evaluation.
# 9:00am - 10:00am
# 10:00am - 11:00am
# 11:00am - 12:00pm
# 12:00pm - 1:00pm
# 1:00pm - 2:00pm
# 2:00pm - 3:00pm
# 3:00pm - 4:00pm
# 4:00pm - 5:00pm
# 5:00pm - 6:00pm
# 6:00pm - 7:00pm
# Skip to registration form3L Capacity: 1Group Study Room. Knoll technology and furniture evaluation.
# 9:00am - 10:00am
# 10:00am - 11:00am
# 11:00am - 12:00pm
# 12:00pm - 1:00pm
# 1:00pm - 2:00pm
# 2:00pm - 3:00pm
# 3:00pm - 4:00pm
# 4:00pm - 5:00pm
# 5:00pm - 6:00pm
# 6:00pm - 7:00pm
# Skip to registration form3N Capacity: 1Group Study Room. Haworth technology and furniture evaluation.
# 9:00am - 10:00am
# 10:00am - 11:00am
# 11:00am - 12:00pm
# 12:00pm - 1:00pm
# 1:00pm - 2:00pm
# 2:00pm - 3:00pm
# 3:00pm - 4:00pm
# 4:00pm - 5:00pm
# 5:00pm - 6:00pm
# 6:00pm - 7:00pm
# Skip to registration form3P Capacity: 1Group Study Room. Collab8 technology evaluation.
# 9:00am - 10:00am
# 10:00am - 11:00am
# 11:00am - 12:00pm
# 12:00pm - 1:00pm
# 1:00pm - 2:00pm
# 2:00pm - 3:00pm
# 3:00pm - 4:00pm
# 4:00pm - 5:00pm
# 5:00pm - 6:00pm
# 6:00pm - 7:00pm
# Skip to registration form3Q Capacity: 1Group Study Room. Collab8 technology evaluation.
# 9:00am - 10:00am
# 10:00am - 11:00am
# 11:00am - 12:00pm
# 12:00pm - 1:00pm
# 1:00pm - 2:00pm
# 2:00pm - 3:00pm
# 3:00pm - 4:00pm
# 4:00pm - 5:00pm
# 5:00pm - 6:00pm
# 6:00pm - 7:00pm
# Skip to registration formGroups have priority. If you make a reservation as an individual, a group may ask you to relocate.(Except for the MMPL iMac Workstations)
# Each reservation has a 10 minute grace period. If your group has not arrived after the first 10 minutes of your reservation have passed, another group may take over your reservation.
# NOTE: If furniture or equipment is lost or damaged while you are in the room, you may be charged for repair or replacement.
# Booking Details
# * Required Field
# Full Name *
# First Name
# Last Name
# Email *
# Enter @usc.edu addresses only
# Submit my Booking

# %%
first_item = book_room_form.find('input',value='60',type='hidden')

# %%
first_item['name']
# Out:
# 'dur545454782'

# %%
first_item_content = first_item.next_sibling

# %%
first_item_content
# Out:
# <input id="t_sch545451998" name="t_sch545451998" type="hidden" value="3F 11:00am - 12:00pm Thursday, July 20, 2017"/>

# %%
book_room_form
# Out:
# <form class="form-horizontal" id="roombookingform" method="POST" role="form">
# <input name="gid" type="hidden" value="4490"/><fieldset class="s-lc-rm-cap-l-1"><legend><h2>3F <small>Capacity: 1</small></h2></legend><div>Group Study Room</div><div class="checkbox">
# <label for="sch545451998">
# <input class="durc" data-seq="12616103" id="sch545451998" name="sid[]" onchange="checkDur('545451998');" type="checkbox" value="545451998"/>
# 						11:00am - 12:00pm
# 					  </label>
# </div><input id="sch545451998dur" name="dur545451998" type="hidden" value="60"/><input id="t_sch545451998" name="t_sch545451998" type="hidden" value="3F 11:00am - 12:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451999">
# <input class="durc" data-seq="12616104" id="sch545451999" name="sid[]" onchange="checkDur('545451999');" type="checkbox" value="545451999"/>
# 						12:00pm - 1:00pm
# 					  </label>
# </div><input id="sch545451999dur" name="dur545451999" type="hidden" value="60"/><input id="t_sch545451999" name="t_sch545451999" type="hidden" value="3F 12:00pm - 1:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545452000">
# <input class="durc" data-seq="12616105" id="sch545452000" name="sid[]" onchange="checkDur('545452000');" type="checkbox" value="545452000"/>
# 						1:00pm - 2:00pm
# 					  </label>
# </div><input id="sch545452000dur" name="dur545452000" type="hidden" value="60"/><input id="t_sch545452000" name="t_sch545452000" type="hidden" value="3F 1:00pm - 2:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545452005">
# <input class="durc" data-seq="12616110" id="sch545452005" name="sid[]" onchange="checkDur('545452005');" type="checkbox" value="545452005"/>
# 						6:00pm - 7:00pm
# 					  </label>
# </div><input id="sch545452005dur" name="dur545452005" type="hidden" value="60"/><input id="t_sch545452005" name="t_sch545452005" type="hidden" value="3F 6:00pm - 7:00pm Thursday, July 20, 2017"/><a class="sr-only" href="#bform">Skip to registration form</a></fieldset><fieldset class="s-lc-rm-cap-l-1"><legend><h2>3G <small>Capacity: 1</small></h2></legend><div>Group Study Room</div><div class="checkbox">
# <label for="sch545451985">
# <input class="durc" data-seq="12617101" id="sch545451985" name="sid[]" onchange="checkDur('545451985');" type="checkbox" value="545451985"/>
# 						9:00am - 10:00am
# 					  </label>
# </div><input id="sch545451985dur" name="dur545451985" type="hidden" value="60"/><input id="t_sch545451985" name="t_sch545451985" type="hidden" value="3G 9:00am - 10:00am Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451986">
# <input class="durc" data-seq="12617102" id="sch545451986" name="sid[]" onchange="checkDur('545451986');" type="checkbox" value="545451986"/>
# 						10:00am - 11:00am
# 					  </label>
# </div><input id="sch545451986dur" name="dur545451986" type="hidden" value="60"/><input id="t_sch545451986" name="t_sch545451986" type="hidden" value="3G 10:00am - 11:00am Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451987">
# <input class="durc" data-seq="12617103" id="sch545451987" name="sid[]" onchange="checkDur('545451987');" type="checkbox" value="545451987"/>
# 						11:00am - 12:00pm
# 					  </label>
# </div><input id="sch545451987dur" name="dur545451987" type="hidden" value="60"/><input id="t_sch545451987" name="t_sch545451987" type="hidden" value="3G 11:00am - 12:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451988">
# <input class="durc" data-seq="12617104" id="sch545451988" name="sid[]" onchange="checkDur('545451988');" type="checkbox" value="545451988"/>
# 						12:00pm - 1:00pm
# 					  </label>
# </div><input id="sch545451988dur" name="dur545451988" type="hidden" value="60"/><input id="t_sch545451988" name="t_sch545451988" type="hidden" value="3G 12:00pm - 1:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451989">
# <input class="durc" data-seq="12617105" id="sch545451989" name="sid[]" onchange="checkDur('545451989');" type="checkbox" value="545451989"/>
# 						1:00pm - 2:00pm
# 					  </label>
# </div><input id="sch545451989dur" name="dur545451989" type="hidden" value="60"/><input id="t_sch545451989" name="t_sch545451989" type="hidden" value="3G 1:00pm - 2:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451992">
# <input class="durc" data-seq="12617108" id="sch545451992" name="sid[]" onchange="checkDur('545451992');" type="checkbox" value="545451992"/>
# 						4:00pm - 5:00pm
# 					  </label>
# </div><input id="sch545451992dur" name="dur545451992" type="hidden" value="60"/><input id="t_sch545451992" name="t_sch545451992" type="hidden" value="3G 4:00pm - 5:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451993">
# <input class="durc" data-seq="12617109" id="sch545451993" name="sid[]" onchange="checkDur('545451993');" type="checkbox" value="545451993"/>
# 						5:00pm - 6:00pm
# 					  </label>
# </div><input id="sch545451993dur" name="dur545451993" type="hidden" value="60"/><input id="t_sch545451993" name="t_sch545451993" type="hidden" value="3G 5:00pm - 6:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451994">
# <input class="durc" data-seq="12617110" id="sch545451994" name="sid[]" onchange="checkDur('545451994');" type="checkbox" value="545451994"/>
# 						6:00pm - 7:00pm
# 					  </label>
# </div><input id="sch545451994dur" name="dur545451994" type="hidden" value="60"/><input id="t_sch545451994" name="t_sch545451994" type="hidden" value="3G 6:00pm - 7:00pm Thursday, July 20, 2017"/><a class="sr-only" href="#bform">Skip to registration form</a></fieldset><fieldset class="s-lc-rm-cap-l-1"><legend><h2>3H <small>Capacity: 1</small></h2></legend><div>Group Study Room</div><div class="checkbox">
# <label for="sch545451974">
# <input class="durc" data-seq="12618101" id="sch545451974" name="sid[]" onchange="checkDur('545451974');" type="checkbox" value="545451974"/>
# 						9:00am - 10:00am
# 					  </label>
# </div><input id="sch545451974dur" name="dur545451974" type="hidden" value="60"/><input id="t_sch545451974" name="t_sch545451974" type="hidden" value="3H 9:00am - 10:00am Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451975">
# <input class="durc" data-seq="12618102" id="sch545451975" name="sid[]" onchange="checkDur('545451975');" type="checkbox" value="545451975"/>
# 						10:00am - 11:00am
# 					  </label>
# </div><input id="sch545451975dur" name="dur545451975" type="hidden" value="60"/><input id="t_sch545451975" name="t_sch545451975" type="hidden" value="3H 10:00am - 11:00am Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451976">
# <input class="durc" data-seq="12618103" id="sch545451976" name="sid[]" onchange="checkDur('545451976');" type="checkbox" value="545451976"/>
# 						11:00am - 12:00pm
# 					  </label>
# </div><input id="sch545451976dur" name="dur545451976" type="hidden" value="60"/><input id="t_sch545451976" name="t_sch545451976" type="hidden" value="3H 11:00am - 12:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451977">
# <input class="durc" data-seq="12618104" id="sch545451977" name="sid[]" onchange="checkDur('545451977');" type="checkbox" value="545451977"/>
# 						12:00pm - 1:00pm
# 					  </label>
# </div><input id="sch545451977dur" name="dur545451977" type="hidden" value="60"/><input id="t_sch545451977" name="t_sch545451977" type="hidden" value="3H 12:00pm - 1:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451980">
# <input class="durc" data-seq="12618107" id="sch545451980" name="sid[]" onchange="checkDur('545451980');" type="checkbox" value="545451980"/>
# 						3:00pm - 4:00pm
# 					  </label>
# </div><input id="sch545451980dur" name="dur545451980" type="hidden" value="60"/><input id="t_sch545451980" name="t_sch545451980" type="hidden" value="3H 3:00pm - 4:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451981">
# <input class="durc" data-seq="12618108" id="sch545451981" name="sid[]" onchange="checkDur('545451981');" type="checkbox" value="545451981"/>
# 						4:00pm - 5:00pm
# 					  </label>
# </div><input id="sch545451981dur" name="dur545451981" type="hidden" value="60"/><input id="t_sch545451981" name="t_sch545451981" type="hidden" value="3H 4:00pm - 5:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451982">
# <input class="durc" data-seq="12618109" id="sch545451982" name="sid[]" onchange="checkDur('545451982');" type="checkbox" value="545451982"/>
# 						5:00pm - 6:00pm
# 					  </label>
# </div><input id="sch545451982dur" name="dur545451982" type="hidden" value="60"/><input id="t_sch545451982" name="t_sch545451982" type="hidden" value="3H 5:00pm - 6:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451983">
# <input class="durc" data-seq="12618110" id="sch545451983" name="sid[]" onchange="checkDur('545451983');" type="checkbox" value="545451983"/>
# 						6:00pm - 7:00pm
# 					  </label>
# </div><input id="sch545451983dur" name="dur545451983" type="hidden" value="60"/><input id="t_sch545451983" name="t_sch545451983" type="hidden" value="3H 6:00pm - 7:00pm Thursday, July 20, 2017"/><a class="sr-only" href="#bform">Skip to registration form</a></fieldset><fieldset class="s-lc-rm-cap-l-1"><legend><h2>3J <small>Capacity: 1</small></h2></legend><div>Group Study Room. Knoll furniture evaluation.</div><div class="checkbox">
# <label for="sch545451963">
# <input class="durc" data-seq="12619101" id="sch545451963" name="sid[]" onchange="checkDur('545451963');" type="checkbox" value="545451963"/>
# 						9:00am - 10:00am
# 					  </label>
# </div><input id="sch545451963dur" name="dur545451963" type="hidden" value="60"/><input id="t_sch545451963" name="t_sch545451963" type="hidden" value="3J 9:00am - 10:00am Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451964">
# <input class="durc" data-seq="12619102" id="sch545451964" name="sid[]" onchange="checkDur('545451964');" type="checkbox" value="545451964"/>
# 						10:00am - 11:00am
# 					  </label>
# </div><input id="sch545451964dur" name="dur545451964" type="hidden" value="60"/><input id="t_sch545451964" name="t_sch545451964" type="hidden" value="3J 10:00am - 11:00am Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451965">
# <input class="durc" data-seq="12619103" id="sch545451965" name="sid[]" onchange="checkDur('545451965');" type="checkbox" value="545451965"/>
# 						11:00am - 12:00pm
# 					  </label>
# </div><input id="sch545451965dur" name="dur545451965" type="hidden" value="60"/><input id="t_sch545451965" name="t_sch545451965" type="hidden" value="3J 11:00am - 12:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451966">
# <input class="durc" data-seq="12619104" id="sch545451966" name="sid[]" onchange="checkDur('545451966');" type="checkbox" value="545451966"/>
# 						12:00pm - 1:00pm
# 					  </label>
# </div><input id="sch545451966dur" name="dur545451966" type="hidden" value="60"/><input id="t_sch545451966" name="t_sch545451966" type="hidden" value="3J 12:00pm - 1:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451967">
# <input class="durc" data-seq="12619105" id="sch545451967" name="sid[]" onchange="checkDur('545451967');" type="checkbox" value="545451967"/>
# 						1:00pm - 2:00pm
# 					  </label>
# </div><input id="sch545451967dur" name="dur545451967" type="hidden" value="60"/><input id="t_sch545451967" name="t_sch545451967" type="hidden" value="3J 1:00pm - 2:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451968">
# <input class="durc" data-seq="12619106" id="sch545451968" name="sid[]" onchange="checkDur('545451968');" type="checkbox" value="545451968"/>
# 						2:00pm - 3:00pm
# 					  </label>
# </div><input id="sch545451968dur" name="dur545451968" type="hidden" value="60"/><input id="t_sch545451968" name="t_sch545451968" type="hidden" value="3J 2:00pm - 3:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451969">
# <input class="durc" data-seq="12619107" id="sch545451969" name="sid[]" onchange="checkDur('545451969');" type="checkbox" value="545451969"/>
# 						3:00pm - 4:00pm
# 					  </label>
# </div><input id="sch545451969dur" name="dur545451969" type="hidden" value="60"/><input id="t_sch545451969" name="t_sch545451969" type="hidden" value="3J 3:00pm - 4:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451970">
# <input class="durc" data-seq="12619108" id="sch545451970" name="sid[]" onchange="checkDur('545451970');" type="checkbox" value="545451970"/>
# 						4:00pm - 5:00pm
# 					  </label>
# </div><input id="sch545451970dur" name="dur545451970" type="hidden" value="60"/><input id="t_sch545451970" name="t_sch545451970" type="hidden" value="3J 4:00pm - 5:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451971">
# <input class="durc" data-seq="12619109" id="sch545451971" name="sid[]" onchange="checkDur('545451971');" type="checkbox" value="545451971"/>
# 						5:00pm - 6:00pm
# 					  </label>
# </div><input id="sch545451971dur" name="dur545451971" type="hidden" value="60"/><input id="t_sch545451971" name="t_sch545451971" type="hidden" value="3J 5:00pm - 6:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451972">
# <input class="durc" data-seq="12619110" id="sch545451972" name="sid[]" onchange="checkDur('545451972');" type="checkbox" value="545451972"/>
# 						6:00pm - 7:00pm
# 					  </label>
# </div><input id="sch545451972dur" name="dur545451972" type="hidden" value="60"/><input id="t_sch545451972" name="t_sch545451972" type="hidden" value="3J 6:00pm - 7:00pm Thursday, July 20, 2017"/><a class="sr-only" href="#bform">Skip to registration form</a></fieldset><fieldset class="s-lc-rm-cap-l-1"><legend><h2>3R <small>Capacity: 1</small></h2></legend><div>Group Study Room</div><div class="checkbox">
# <label for="sch545451952">
# <input class="durc" data-seq="12620101" id="sch545451952" name="sid[]" onchange="checkDur('545451952');" type="checkbox" value="545451952"/>
# 						9:00am - 10:00am
# 					  </label>
# </div><input id="sch545451952dur" name="dur545451952" type="hidden" value="60"/><input id="t_sch545451952" name="t_sch545451952" type="hidden" value="3R 9:00am - 10:00am Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451953">
# <input class="durc" data-seq="12620102" id="sch545451953" name="sid[]" onchange="checkDur('545451953');" type="checkbox" value="545451953"/>
# 						10:00am - 11:00am
# 					  </label>
# </div><input id="sch545451953dur" name="dur545451953" type="hidden" value="60"/><input id="t_sch545451953" name="t_sch545451953" type="hidden" value="3R 10:00am - 11:00am Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451954">
# <input class="durc" data-seq="12620103" id="sch545451954" name="sid[]" onchange="checkDur('545451954');" type="checkbox" value="545451954"/>
# 						11:00am - 12:00pm
# 					  </label>
# </div><input id="sch545451954dur" name="dur545451954" type="hidden" value="60"/><input id="t_sch545451954" name="t_sch545451954" type="hidden" value="3R 11:00am - 12:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451955">
# <input class="durc" data-seq="12620104" id="sch545451955" name="sid[]" onchange="checkDur('545451955');" type="checkbox" value="545451955"/>
# 						12:00pm - 1:00pm
# 					  </label>
# </div><input id="sch545451955dur" name="dur545451955" type="hidden" value="60"/><input id="t_sch545451955" name="t_sch545451955" type="hidden" value="3R 12:00pm - 1:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451956">
# <input class="durc" data-seq="12620105" id="sch545451956" name="sid[]" onchange="checkDur('545451956');" type="checkbox" value="545451956"/>
# 						1:00pm - 2:00pm
# 					  </label>
# </div><input id="sch545451956dur" name="dur545451956" type="hidden" value="60"/><input id="t_sch545451956" name="t_sch545451956" type="hidden" value="3R 1:00pm - 2:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451957">
# <input class="durc" data-seq="12620106" id="sch545451957" name="sid[]" onchange="checkDur('545451957');" type="checkbox" value="545451957"/>
# 						2:00pm - 3:00pm
# 					  </label>
# </div><input id="sch545451957dur" name="dur545451957" type="hidden" value="60"/><input id="t_sch545451957" name="t_sch545451957" type="hidden" value="3R 2:00pm - 3:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451958">
# <input class="durc" data-seq="12620107" id="sch545451958" name="sid[]" onchange="checkDur('545451958');" type="checkbox" value="545451958"/>
# 						3:00pm - 4:00pm
# 					  </label>
# </div><input id="sch545451958dur" name="dur545451958" type="hidden" value="60"/><input id="t_sch545451958" name="t_sch545451958" type="hidden" value="3R 3:00pm - 4:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451959">
# <input class="durc" data-seq="12620108" id="sch545451959" name="sid[]" onchange="checkDur('545451959');" type="checkbox" value="545451959"/>
# 						4:00pm - 5:00pm
# 					  </label>
# </div><input id="sch545451959dur" name="dur545451959" type="hidden" value="60"/><input id="t_sch545451959" name="t_sch545451959" type="hidden" value="3R 4:00pm - 5:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451960">
# <input class="durc" data-seq="12620109" id="sch545451960" name="sid[]" onchange="checkDur('545451960');" type="checkbox" value="545451960"/>
# 						5:00pm - 6:00pm
# 					  </label>
# </div><input id="sch545451960dur" name="dur545451960" type="hidden" value="60"/><input id="t_sch545451960" name="t_sch545451960" type="hidden" value="3R 5:00pm - 6:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451961">
# <input class="durc" data-seq="12620110" id="sch545451961" name="sid[]" onchange="checkDur('545451961');" type="checkbox" value="545451961"/>
# 						6:00pm - 7:00pm
# 					  </label>
# </div><input id="sch545451961dur" name="dur545451961" type="hidden" value="60"/><input id="t_sch545451961" name="t_sch545451961" type="hidden" value="3R 6:00pm - 7:00pm Thursday, July 20, 2017"/><a class="sr-only" href="#bform">Skip to registration form</a></fieldset><fieldset class="s-lc-rm-cap-l-1"><legend><h2>3S <small>Capacity: 1</small></h2></legend><div>Group Study Room</div><div class="checkbox">
# <label for="sch545451941">
# <input class="durc" data-seq="12621101" id="sch545451941" name="sid[]" onchange="checkDur('545451941');" type="checkbox" value="545451941"/>
# 						9:00am - 10:00am
# 					  </label>
# </div><input id="sch545451941dur" name="dur545451941" type="hidden" value="60"/><input id="t_sch545451941" name="t_sch545451941" type="hidden" value="3S 9:00am - 10:00am Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451942">
# <input class="durc" data-seq="12621102" id="sch545451942" name="sid[]" onchange="checkDur('545451942');" type="checkbox" value="545451942"/>
# 						10:00am - 11:00am
# 					  </label>
# </div><input id="sch545451942dur" name="dur545451942" type="hidden" value="60"/><input id="t_sch545451942" name="t_sch545451942" type="hidden" value="3S 10:00am - 11:00am Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451943">
# <input class="durc" data-seq="12621103" id="sch545451943" name="sid[]" onchange="checkDur('545451943');" type="checkbox" value="545451943"/>
# 						11:00am - 12:00pm
# 					  </label>
# </div><input id="sch545451943dur" name="dur545451943" type="hidden" value="60"/><input id="t_sch545451943" name="t_sch545451943" type="hidden" value="3S 11:00am - 12:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451944">
# <input class="durc" data-seq="12621104" id="sch545451944" name="sid[]" onchange="checkDur('545451944');" type="checkbox" value="545451944"/>
# 						12:00pm - 1:00pm
# 					  </label>
# </div><input id="sch545451944dur" name="dur545451944" type="hidden" value="60"/><input id="t_sch545451944" name="t_sch545451944" type="hidden" value="3S 12:00pm - 1:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451945">
# <input class="durc" data-seq="12621105" id="sch545451945" name="sid[]" onchange="checkDur('545451945');" type="checkbox" value="545451945"/>
# 						1:00pm - 2:00pm
# 					  </label>
# </div><input id="sch545451945dur" name="dur545451945" type="hidden" value="60"/><input id="t_sch545451945" name="t_sch545451945" type="hidden" value="3S 1:00pm - 2:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451946">
# <input class="durc" data-seq="12621106" id="sch545451946" name="sid[]" onchange="checkDur('545451946');" type="checkbox" value="545451946"/>
# 						2:00pm - 3:00pm
# 					  </label>
# </div><input id="sch545451946dur" name="dur545451946" type="hidden" value="60"/><input id="t_sch545451946" name="t_sch545451946" type="hidden" value="3S 2:00pm - 3:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451947">
# <input class="durc" data-seq="12621107" id="sch545451947" name="sid[]" onchange="checkDur('545451947');" type="checkbox" value="545451947"/>
# 						3:00pm - 4:00pm
# 					  </label>
# </div><input id="sch545451947dur" name="dur545451947" type="hidden" value="60"/><input id="t_sch545451947" name="t_sch545451947" type="hidden" value="3S 3:00pm - 4:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451948">
# <input class="durc" data-seq="12621108" id="sch545451948" name="sid[]" onchange="checkDur('545451948');" type="checkbox" value="545451948"/>
# 						4:00pm - 5:00pm
# 					  </label>
# </div><input id="sch545451948dur" name="dur545451948" type="hidden" value="60"/><input id="t_sch545451948" name="t_sch545451948" type="hidden" value="3S 4:00pm - 5:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451949">
# <input class="durc" data-seq="12621109" id="sch545451949" name="sid[]" onchange="checkDur('545451949');" type="checkbox" value="545451949"/>
# 						5:00pm - 6:00pm
# 					  </label>
# </div><input id="sch545451949dur" name="dur545451949" type="hidden" value="60"/><input id="t_sch545451949" name="t_sch545451949" type="hidden" value="3S 5:00pm - 6:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451950">
# <input class="durc" data-seq="12621110" id="sch545451950" name="sid[]" onchange="checkDur('545451950');" type="checkbox" value="545451950"/>
# 						6:00pm - 7:00pm
# 					  </label>
# </div><input id="sch545451950dur" name="dur545451950" type="hidden" value="60"/><input id="t_sch545451950" name="t_sch545451950" type="hidden" value="3S 6:00pm - 7:00pm Thursday, July 20, 2017"/><a class="sr-only" href="#bform">Skip to registration form</a></fieldset><fieldset class="s-lc-rm-cap-l-1"><legend><h2>3T <small>Capacity: 1</small></h2></legend><div>Group Study Room</div><div class="checkbox">
# <label for="sch545451930">
# <input class="durc" data-seq="12622101" id="sch545451930" name="sid[]" onchange="checkDur('545451930');" type="checkbox" value="545451930"/>
# 						9:00am - 10:00am
# 					  </label>
# </div><input id="sch545451930dur" name="dur545451930" type="hidden" value="60"/><input id="t_sch545451930" name="t_sch545451930" type="hidden" value="3T 9:00am - 10:00am Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451931">
# <input class="durc" data-seq="12622102" id="sch545451931" name="sid[]" onchange="checkDur('545451931');" type="checkbox" value="545451931"/>
# 						10:00am - 11:00am
# 					  </label>
# </div><input id="sch545451931dur" name="dur545451931" type="hidden" value="60"/><input id="t_sch545451931" name="t_sch545451931" type="hidden" value="3T 10:00am - 11:00am Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451932">
# <input class="durc" data-seq="12622103" id="sch545451932" name="sid[]" onchange="checkDur('545451932');" type="checkbox" value="545451932"/>
# 						11:00am - 12:00pm
# 					  </label>
# </div><input id="sch545451932dur" name="dur545451932" type="hidden" value="60"/><input id="t_sch545451932" name="t_sch545451932" type="hidden" value="3T 11:00am - 12:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451933">
# <input class="durc" data-seq="12622104" id="sch545451933" name="sid[]" onchange="checkDur('545451933');" type="checkbox" value="545451933"/>
# 						12:00pm - 1:00pm
# 					  </label>
# </div><input id="sch545451933dur" name="dur545451933" type="hidden" value="60"/><input id="t_sch545451933" name="t_sch545451933" type="hidden" value="3T 12:00pm - 1:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451934">
# <input class="durc" data-seq="12622105" id="sch545451934" name="sid[]" onchange="checkDur('545451934');" type="checkbox" value="545451934"/>
# 						1:00pm - 2:00pm
# 					  </label>
# </div><input id="sch545451934dur" name="dur545451934" type="hidden" value="60"/><input id="t_sch545451934" name="t_sch545451934" type="hidden" value="3T 1:00pm - 2:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451935">
# <input class="durc" data-seq="12622106" id="sch545451935" name="sid[]" onchange="checkDur('545451935');" type="checkbox" value="545451935"/>
# 						2:00pm - 3:00pm
# 					  </label>
# </div><input id="sch545451935dur" name="dur545451935" type="hidden" value="60"/><input id="t_sch545451935" name="t_sch545451935" type="hidden" value="3T 2:00pm - 3:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451936">
# <input class="durc" data-seq="12622107" id="sch545451936" name="sid[]" onchange="checkDur('545451936');" type="checkbox" value="545451936"/>
# 						3:00pm - 4:00pm
# 					  </label>
# </div><input id="sch545451936dur" name="dur545451936" type="hidden" value="60"/><input id="t_sch545451936" name="t_sch545451936" type="hidden" value="3T 3:00pm - 4:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451937">
# <input class="durc" data-seq="12622108" id="sch545451937" name="sid[]" onchange="checkDur('545451937');" type="checkbox" value="545451937"/>
# 						4:00pm - 5:00pm
# 					  </label>
# </div><input id="sch545451937dur" name="dur545451937" type="hidden" value="60"/><input id="t_sch545451937" name="t_sch545451937" type="hidden" value="3T 4:00pm - 5:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451938">
# <input class="durc" data-seq="12622109" id="sch545451938" name="sid[]" onchange="checkDur('545451938');" type="checkbox" value="545451938"/>
# 						5:00pm - 6:00pm
# 					  </label>
# </div><input id="sch545451938dur" name="dur545451938" type="hidden" value="60"/><input id="t_sch545451938" name="t_sch545451938" type="hidden" value="3T 5:00pm - 6:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451939">
# <input class="durc" data-seq="12622110" id="sch545451939" name="sid[]" onchange="checkDur('545451939');" type="checkbox" value="545451939"/>
# 						6:00pm - 7:00pm
# 					  </label>
# </div><input id="sch545451939dur" name="dur545451939" type="hidden" value="60"/><input id="t_sch545451939" name="t_sch545451939" type="hidden" value="3T 6:00pm - 7:00pm Thursday, July 20, 2017"/><a class="sr-only" href="#bform">Skip to registration form</a></fieldset><fieldset class="s-lc-rm-cap-l-1"><legend><h2>3U <small>Capacity: 1</small></h2></legend><div>Group Study Room</div><div class="checkbox">
# <label for="sch545451919">
# <input class="durc" data-seq="12623101" id="sch545451919" name="sid[]" onchange="checkDur('545451919');" type="checkbox" value="545451919"/>
# 						9:00am - 10:00am
# 					  </label>
# </div><input id="sch545451919dur" name="dur545451919" type="hidden" value="60"/><input id="t_sch545451919" name="t_sch545451919" type="hidden" value="3U 9:00am - 10:00am Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451920">
# <input class="durc" data-seq="12623102" id="sch545451920" name="sid[]" onchange="checkDur('545451920');" type="checkbox" value="545451920"/>
# 						10:00am - 11:00am
# 					  </label>
# </div><input id="sch545451920dur" name="dur545451920" type="hidden" value="60"/><input id="t_sch545451920" name="t_sch545451920" type="hidden" value="3U 10:00am - 11:00am Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451921">
# <input class="durc" data-seq="12623103" id="sch545451921" name="sid[]" onchange="checkDur('545451921');" type="checkbox" value="545451921"/>
# 						11:00am - 12:00pm
# 					  </label>
# </div><input id="sch545451921dur" name="dur545451921" type="hidden" value="60"/><input id="t_sch545451921" name="t_sch545451921" type="hidden" value="3U 11:00am - 12:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451922">
# <input class="durc" data-seq="12623104" id="sch545451922" name="sid[]" onchange="checkDur('545451922');" type="checkbox" value="545451922"/>
# 						12:00pm - 1:00pm
# 					  </label>
# </div><input id="sch545451922dur" name="dur545451922" type="hidden" value="60"/><input id="t_sch545451922" name="t_sch545451922" type="hidden" value="3U 12:00pm - 1:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451923">
# <input class="durc" data-seq="12623105" id="sch545451923" name="sid[]" onchange="checkDur('545451923');" type="checkbox" value="545451923"/>
# 						1:00pm - 2:00pm
# 					  </label>
# </div><input id="sch545451923dur" name="dur545451923" type="hidden" value="60"/><input id="t_sch545451923" name="t_sch545451923" type="hidden" value="3U 1:00pm - 2:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451924">
# <input class="durc" data-seq="12623106" id="sch545451924" name="sid[]" onchange="checkDur('545451924');" type="checkbox" value="545451924"/>
# 						2:00pm - 3:00pm
# 					  </label>
# </div><input id="sch545451924dur" name="dur545451924" type="hidden" value="60"/><input id="t_sch545451924" name="t_sch545451924" type="hidden" value="3U 2:00pm - 3:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451925">
# <input class="durc" data-seq="12623107" id="sch545451925" name="sid[]" onchange="checkDur('545451925');" type="checkbox" value="545451925"/>
# 						3:00pm - 4:00pm
# 					  </label>
# </div><input id="sch545451925dur" name="dur545451925" type="hidden" value="60"/><input id="t_sch545451925" name="t_sch545451925" type="hidden" value="3U 3:00pm - 4:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451926">
# <input class="durc" data-seq="12623108" id="sch545451926" name="sid[]" onchange="checkDur('545451926');" type="checkbox" value="545451926"/>
# 						4:00pm - 5:00pm
# 					  </label>
# </div><input id="sch545451926dur" name="dur545451926" type="hidden" value="60"/><input id="t_sch545451926" name="t_sch545451926" type="hidden" value="3U 4:00pm - 5:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451927">
# <input class="durc" data-seq="12623109" id="sch545451927" name="sid[]" onchange="checkDur('545451927');" type="checkbox" value="545451927"/>
# 						5:00pm - 6:00pm
# 					  </label>
# </div><input id="sch545451927dur" name="dur545451927" type="hidden" value="60"/><input id="t_sch545451927" name="t_sch545451927" type="hidden" value="3U 5:00pm - 6:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451928">
# <input class="durc" data-seq="12623110" id="sch545451928" name="sid[]" onchange="checkDur('545451928');" type="checkbox" value="545451928"/>
# 						6:00pm - 7:00pm
# 					  </label>
# </div><input id="sch545451928dur" name="dur545451928" type="hidden" value="60"/><input id="t_sch545451928" name="t_sch545451928" type="hidden" value="3U 6:00pm - 7:00pm Thursday, July 20, 2017"/><a class="sr-only" href="#bform">Skip to registration form</a></fieldset><fieldset class="s-lc-rm-cap-l-1"><legend><h2>3W <small>Capacity: 1</small></h2></legend><div>Group Study Room</div><div class="checkbox">
# <label for="sch545451908">
# <input class="durc" data-seq="12624101" id="sch545451908" name="sid[]" onchange="checkDur('545451908');" type="checkbox" value="545451908"/>
# 						9:00am - 10:00am
# 					  </label>
# </div><input id="sch545451908dur" name="dur545451908" type="hidden" value="60"/><input id="t_sch545451908" name="t_sch545451908" type="hidden" value="3W 9:00am - 10:00am Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451909">
# <input class="durc" data-seq="12624102" id="sch545451909" name="sid[]" onchange="checkDur('545451909');" type="checkbox" value="545451909"/>
# 						10:00am - 11:00am
# 					  </label>
# </div><input id="sch545451909dur" name="dur545451909" type="hidden" value="60"/><input id="t_sch545451909" name="t_sch545451909" type="hidden" value="3W 10:00am - 11:00am Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451910">
# <input class="durc" data-seq="12624103" id="sch545451910" name="sid[]" onchange="checkDur('545451910');" type="checkbox" value="545451910"/>
# 						11:00am - 12:00pm
# 					  </label>
# </div><input id="sch545451910dur" name="dur545451910" type="hidden" value="60"/><input id="t_sch545451910" name="t_sch545451910" type="hidden" value="3W 11:00am - 12:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451911">
# <input class="durc" data-seq="12624104" id="sch545451911" name="sid[]" onchange="checkDur('545451911');" type="checkbox" value="545451911"/>
# 						12:00pm - 1:00pm
# 					  </label>
# </div><input id="sch545451911dur" name="dur545451911" type="hidden" value="60"/><input id="t_sch545451911" name="t_sch545451911" type="hidden" value="3W 12:00pm - 1:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451912">
# <input class="durc" data-seq="12624105" id="sch545451912" name="sid[]" onchange="checkDur('545451912');" type="checkbox" value="545451912"/>
# 						1:00pm - 2:00pm
# 					  </label>
# </div><input id="sch545451912dur" name="dur545451912" type="hidden" value="60"/><input id="t_sch545451912" name="t_sch545451912" type="hidden" value="3W 1:00pm - 2:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451913">
# <input class="durc" data-seq="12624106" id="sch545451913" name="sid[]" onchange="checkDur('545451913');" type="checkbox" value="545451913"/>
# 						2:00pm - 3:00pm
# 					  </label>
# </div><input id="sch545451913dur" name="dur545451913" type="hidden" value="60"/><input id="t_sch545451913" name="t_sch545451913" type="hidden" value="3W 2:00pm - 3:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451914">
# <input class="durc" data-seq="12624107" id="sch545451914" name="sid[]" onchange="checkDur('545451914');" type="checkbox" value="545451914"/>
# 						3:00pm - 4:00pm
# 					  </label>
# </div><input id="sch545451914dur" name="dur545451914" type="hidden" value="60"/><input id="t_sch545451914" name="t_sch545451914" type="hidden" value="3W 3:00pm - 4:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451915">
# <input class="durc" data-seq="12624108" id="sch545451915" name="sid[]" onchange="checkDur('545451915');" type="checkbox" value="545451915"/>
# 						4:00pm - 5:00pm
# 					  </label>
# </div><input id="sch545451915dur" name="dur545451915" type="hidden" value="60"/><input id="t_sch545451915" name="t_sch545451915" type="hidden" value="3W 4:00pm - 5:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451916">
# <input class="durc" data-seq="12624109" id="sch545451916" name="sid[]" onchange="checkDur('545451916');" type="checkbox" value="545451916"/>
# 						5:00pm - 6:00pm
# 					  </label>
# </div><input id="sch545451916dur" name="dur545451916" type="hidden" value="60"/><input id="t_sch545451916" name="t_sch545451916" type="hidden" value="3W 5:00pm - 6:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451917">
# <input class="durc" data-seq="12624110" id="sch545451917" name="sid[]" onchange="checkDur('545451917');" type="checkbox" value="545451917"/>
# 						6:00pm - 7:00pm
# 					  </label>
# </div><input id="sch545451917dur" name="dur545451917" type="hidden" value="60"/><input id="t_sch545451917" name="t_sch545451917" type="hidden" value="3W 6:00pm - 7:00pm Thursday, July 20, 2017"/><a class="sr-only" href="#bform">Skip to registration form</a></fieldset><fieldset class="s-lc-rm-cap-l-1"><legend><h2>3X <small>Capacity: 1</small></h2></legend><div>Group Study Room</div><div class="checkbox">
# <label for="sch545451897">
# <input class="durc" data-seq="12625101" id="sch545451897" name="sid[]" onchange="checkDur('545451897');" type="checkbox" value="545451897"/>
# 						9:00am - 10:00am
# 					  </label>
# </div><input id="sch545451897dur" name="dur545451897" type="hidden" value="60"/><input id="t_sch545451897" name="t_sch545451897" type="hidden" value="3X 9:00am - 10:00am Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451898">
# <input class="durc" data-seq="12625102" id="sch545451898" name="sid[]" onchange="checkDur('545451898');" type="checkbox" value="545451898"/>
# 						10:00am - 11:00am
# 					  </label>
# </div><input id="sch545451898dur" name="dur545451898" type="hidden" value="60"/><input id="t_sch545451898" name="t_sch545451898" type="hidden" value="3X 10:00am - 11:00am Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451899">
# <input class="durc" data-seq="12625103" id="sch545451899" name="sid[]" onchange="checkDur('545451899');" type="checkbox" value="545451899"/>
# 						11:00am - 12:00pm
# 					  </label>
# </div><input id="sch545451899dur" name="dur545451899" type="hidden" value="60"/><input id="t_sch545451899" name="t_sch545451899" type="hidden" value="3X 11:00am - 12:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451900">
# <input class="durc" data-seq="12625104" id="sch545451900" name="sid[]" onchange="checkDur('545451900');" type="checkbox" value="545451900"/>
# 						12:00pm - 1:00pm
# 					  </label>
# </div><input id="sch545451900dur" name="dur545451900" type="hidden" value="60"/><input id="t_sch545451900" name="t_sch545451900" type="hidden" value="3X 12:00pm - 1:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451901">
# <input class="durc" data-seq="12625105" id="sch545451901" name="sid[]" onchange="checkDur('545451901');" type="checkbox" value="545451901"/>
# 						1:00pm - 2:00pm
# 					  </label>
# </div><input id="sch545451901dur" name="dur545451901" type="hidden" value="60"/><input id="t_sch545451901" name="t_sch545451901" type="hidden" value="3X 1:00pm - 2:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451902">
# <input class="durc" data-seq="12625106" id="sch545451902" name="sid[]" onchange="checkDur('545451902');" type="checkbox" value="545451902"/>
# 						2:00pm - 3:00pm
# 					  </label>
# </div><input id="sch545451902dur" name="dur545451902" type="hidden" value="60"/><input id="t_sch545451902" name="t_sch545451902" type="hidden" value="3X 2:00pm - 3:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451903">
# <input class="durc" data-seq="12625107" id="sch545451903" name="sid[]" onchange="checkDur('545451903');" type="checkbox" value="545451903"/>
# 						3:00pm - 4:00pm
# 					  </label>
# </div><input id="sch545451903dur" name="dur545451903" type="hidden" value="60"/><input id="t_sch545451903" name="t_sch545451903" type="hidden" value="3X 3:00pm - 4:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451904">
# <input class="durc" data-seq="12625108" id="sch545451904" name="sid[]" onchange="checkDur('545451904');" type="checkbox" value="545451904"/>
# 						4:00pm - 5:00pm
# 					  </label>
# </div><input id="sch545451904dur" name="dur545451904" type="hidden" value="60"/><input id="t_sch545451904" name="t_sch545451904" type="hidden" value="3X 4:00pm - 5:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451905">
# <input class="durc" data-seq="12625109" id="sch545451905" name="sid[]" onchange="checkDur('545451905');" type="checkbox" value="545451905"/>
# 						5:00pm - 6:00pm
# 					  </label>
# </div><input id="sch545451905dur" name="dur545451905" type="hidden" value="60"/><input id="t_sch545451905" name="t_sch545451905" type="hidden" value="3X 5:00pm - 6:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451906">
# <input class="durc" data-seq="12625110" id="sch545451906" name="sid[]" onchange="checkDur('545451906');" type="checkbox" value="545451906"/>
# 						6:00pm - 7:00pm
# 					  </label>
# </div><input id="sch545451906dur" name="dur545451906" type="hidden" value="60"/><input id="t_sch545451906" name="t_sch545451906" type="hidden" value="3X 6:00pm - 7:00pm Thursday, July 20, 2017"/><a class="sr-only" href="#bform">Skip to registration form</a></fieldset><fieldset class="s-lc-rm-cap-l-1"><legend><h2>3AA <small>Capacity: 1</small></h2></legend><div>Group Study Room</div><div class="checkbox">
# <label for="sch545452062">
# <input class="durc" data-seq="12627101" id="sch545452062" name="sid[]" onchange="checkDur('545452062');" type="checkbox" value="545452062"/>
# 						9:00am - 10:00am
# 					  </label>
# </div><input id="sch545452062dur" name="dur545452062" type="hidden" value="60"/><input id="t_sch545452062" name="t_sch545452062" type="hidden" value="3AA 9:00am - 10:00am Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545452063">
# <input class="durc" data-seq="12627102" id="sch545452063" name="sid[]" onchange="checkDur('545452063');" type="checkbox" value="545452063"/>
# 						10:00am - 11:00am
# 					  </label>
# </div><input id="sch545452063dur" name="dur545452063" type="hidden" value="60"/><input id="t_sch545452063" name="t_sch545452063" type="hidden" value="3AA 10:00am - 11:00am Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545452064">
# <input class="durc" data-seq="12627103" id="sch545452064" name="sid[]" onchange="checkDur('545452064');" type="checkbox" value="545452064"/>
# 						11:00am - 12:00pm
# 					  </label>
# </div><input id="sch545452064dur" name="dur545452064" type="hidden" value="60"/><input id="t_sch545452064" name="t_sch545452064" type="hidden" value="3AA 11:00am - 12:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545452065">
# <input class="durc" data-seq="12627104" id="sch545452065" name="sid[]" onchange="checkDur('545452065');" type="checkbox" value="545452065"/>
# 						12:00pm - 1:00pm
# 					  </label>
# </div><input id="sch545452065dur" name="dur545452065" type="hidden" value="60"/><input id="t_sch545452065" name="t_sch545452065" type="hidden" value="3AA 12:00pm - 1:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545452066">
# <input class="durc" data-seq="12627105" id="sch545452066" name="sid[]" onchange="checkDur('545452066');" type="checkbox" value="545452066"/>
# 						1:00pm - 2:00pm
# 					  </label>
# </div><input id="sch545452066dur" name="dur545452066" type="hidden" value="60"/><input id="t_sch545452066" name="t_sch545452066" type="hidden" value="3AA 1:00pm - 2:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545452067">
# <input class="durc" data-seq="12627106" id="sch545452067" name="sid[]" onchange="checkDur('545452067');" type="checkbox" value="545452067"/>
# 						2:00pm - 3:00pm
# 					  </label>
# </div><input id="sch545452067dur" name="dur545452067" type="hidden" value="60"/><input id="t_sch545452067" name="t_sch545452067" type="hidden" value="3AA 2:00pm - 3:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545452068">
# <input class="durc" data-seq="12627107" id="sch545452068" name="sid[]" onchange="checkDur('545452068');" type="checkbox" value="545452068"/>
# 						3:00pm - 4:00pm
# 					  </label>
# </div><input id="sch545452068dur" name="dur545452068" type="hidden" value="60"/><input id="t_sch545452068" name="t_sch545452068" type="hidden" value="3AA 3:00pm - 4:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545452069">
# <input class="durc" data-seq="12627108" id="sch545452069" name="sid[]" onchange="checkDur('545452069');" type="checkbox" value="545452069"/>
# 						4:00pm - 5:00pm
# 					  </label>
# </div><input id="sch545452069dur" name="dur545452069" type="hidden" value="60"/><input id="t_sch545452069" name="t_sch545452069" type="hidden" value="3AA 4:00pm - 5:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545452070">
# <input class="durc" data-seq="12627109" id="sch545452070" name="sid[]" onchange="checkDur('545452070');" type="checkbox" value="545452070"/>
# 						5:00pm - 6:00pm
# 					  </label>
# </div><input id="sch545452070dur" name="dur545452070" type="hidden" value="60"/><input id="t_sch545452070" name="t_sch545452070" type="hidden" value="3AA 5:00pm - 6:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545452071">
# <input class="durc" data-seq="12627110" id="sch545452071" name="sid[]" onchange="checkDur('545452071');" type="checkbox" value="545452071"/>
# 						6:00pm - 7:00pm
# 					  </label>
# </div><input id="sch545452071dur" name="dur545452071" type="hidden" value="60"/><input id="t_sch545452071" name="t_sch545452071" type="hidden" value="3AA 6:00pm - 7:00pm Thursday, July 20, 2017"/><a class="sr-only" href="#bform">Skip to registration form</a></fieldset><fieldset class="s-lc-rm-cap-l-1"><legend><h2>3K <small>Capacity: 1</small></h2></legend><div>Group Study Room. Haworth technology and furniture evaluation.</div><div class="checkbox">
# <label for="sch545451886">
# <input class="durc" data-seq="12446101" id="sch545451886" name="sid[]" onchange="checkDur('545451886');" type="checkbox" value="545451886"/>
# 						9:00am - 10:00am
# 					  </label>
# </div><input id="sch545451886dur" name="dur545451886" type="hidden" value="60"/><input id="t_sch545451886" name="t_sch545451886" type="hidden" value="3K 9:00am - 10:00am Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451887">
# <input class="durc" data-seq="12446102" id="sch545451887" name="sid[]" onchange="checkDur('545451887');" type="checkbox" value="545451887"/>
# 						10:00am - 11:00am
# 					  </label>
# </div><input id="sch545451887dur" name="dur545451887" type="hidden" value="60"/><input id="t_sch545451887" name="t_sch545451887" type="hidden" value="3K 10:00am - 11:00am Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451888">
# <input class="durc" data-seq="12446103" id="sch545451888" name="sid[]" onchange="checkDur('545451888');" type="checkbox" value="545451888"/>
# 						11:00am - 12:00pm
# 					  </label>
# </div><input id="sch545451888dur" name="dur545451888" type="hidden" value="60"/><input id="t_sch545451888" name="t_sch545451888" type="hidden" value="3K 11:00am - 12:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451889">
# <input class="durc" data-seq="12446104" id="sch545451889" name="sid[]" onchange="checkDur('545451889');" type="checkbox" value="545451889"/>
# 						12:00pm - 1:00pm
# 					  </label>
# </div><input id="sch545451889dur" name="dur545451889" type="hidden" value="60"/><input id="t_sch545451889" name="t_sch545451889" type="hidden" value="3K 12:00pm - 1:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451890">
# <input class="durc" data-seq="12446105" id="sch545451890" name="sid[]" onchange="checkDur('545451890');" type="checkbox" value="545451890"/>
# 						1:00pm - 2:00pm
# 					  </label>
# </div><input id="sch545451890dur" name="dur545451890" type="hidden" value="60"/><input id="t_sch545451890" name="t_sch545451890" type="hidden" value="3K 1:00pm - 2:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451891">
# <input class="durc" data-seq="12446106" id="sch545451891" name="sid[]" onchange="checkDur('545451891');" type="checkbox" value="545451891"/>
# 						2:00pm - 3:00pm
# 					  </label>
# </div><input id="sch545451891dur" name="dur545451891" type="hidden" value="60"/><input id="t_sch545451891" name="t_sch545451891" type="hidden" value="3K 2:00pm - 3:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451892">
# <input class="durc" data-seq="12446107" id="sch545451892" name="sid[]" onchange="checkDur('545451892');" type="checkbox" value="545451892"/>
# 						3:00pm - 4:00pm
# 					  </label>
# </div><input id="sch545451892dur" name="dur545451892" type="hidden" value="60"/><input id="t_sch545451892" name="t_sch545451892" type="hidden" value="3K 3:00pm - 4:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545451893">
# ...
# <label for="sch545452060">
# <input class="durc" data-seq="12447110" id="sch545452060" name="sid[]" onchange="checkDur('545452060');" type="checkbox" value="545452060"/>
# 						6:00pm - 7:00pm
# 					  </label>
# </div><input id="sch545452060dur" name="dur545452060" type="hidden" value="60"/><input id="t_sch545452060" name="t_sch545452060" type="hidden" value="3L 6:00pm - 7:00pm Thursday, July 20, 2017"/><a class="sr-only" href="#bform">Skip to registration form</a></fieldset><fieldset class="s-lc-rm-cap-l-1"><legend><h2>3N <small>Capacity: 1</small></h2></legend><div>Group Study Room. Haworth technology and furniture evaluation.</div><div class="checkbox">
# <label for="sch545452029">
# <input class="durc" data-seq="12449101" id="sch545452029" name="sid[]" onchange="checkDur('545452029');" type="checkbox" value="545452029"/>
# 						9:00am - 10:00am
# 					  </label>
# </div><input id="sch545452029dur" name="dur545452029" type="hidden" value="60"/><input id="t_sch545452029" name="t_sch545452029" type="hidden" value="3N 9:00am - 10:00am Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545452030">
# <input class="durc" data-seq="12449102" id="sch545452030" name="sid[]" onchange="checkDur('545452030');" type="checkbox" value="545452030"/>
# 						10:00am - 11:00am
# 					  </label>
# </div><input id="sch545452030dur" name="dur545452030" type="hidden" value="60"/><input id="t_sch545452030" name="t_sch545452030" type="hidden" value="3N 10:00am - 11:00am Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545452031">
# <input class="durc" data-seq="12449103" id="sch545452031" name="sid[]" onchange="checkDur('545452031');" type="checkbox" value="545452031"/>
# 						11:00am - 12:00pm
# 					  </label>
# </div><input id="sch545452031dur" name="dur545452031" type="hidden" value="60"/><input id="t_sch545452031" name="t_sch545452031" type="hidden" value="3N 11:00am - 12:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545452032">
# <input class="durc" data-seq="12449104" id="sch545452032" name="sid[]" onchange="checkDur('545452032');" type="checkbox" value="545452032"/>
# 						12:00pm - 1:00pm
# 					  </label>
# </div><input id="sch545452032dur" name="dur545452032" type="hidden" value="60"/><input id="t_sch545452032" name="t_sch545452032" type="hidden" value="3N 12:00pm - 1:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545452033">
# <input class="durc" data-seq="12449105" id="sch545452033" name="sid[]" onchange="checkDur('545452033');" type="checkbox" value="545452033"/>
# 						1:00pm - 2:00pm
# 					  </label>
# </div><input id="sch545452033dur" name="dur545452033" type="hidden" value="60"/><input id="t_sch545452033" name="t_sch545452033" type="hidden" value="3N 1:00pm - 2:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545452034">
# <input class="durc" data-seq="12449106" id="sch545452034" name="sid[]" onchange="checkDur('545452034');" type="checkbox" value="545452034"/>
# 						2:00pm - 3:00pm
# 					  </label>
# </div><input id="sch545452034dur" name="dur545452034" type="hidden" value="60"/><input id="t_sch545452034" name="t_sch545452034" type="hidden" value="3N 2:00pm - 3:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545452035">
# <input class="durc" data-seq="12449107" id="sch545452035" name="sid[]" onchange="checkDur('545452035');" type="checkbox" value="545452035"/>
# 						3:00pm - 4:00pm
# 					  </label>
# </div><input id="sch545452035dur" name="dur545452035" type="hidden" value="60"/><input id="t_sch545452035" name="t_sch545452035" type="hidden" value="3N 3:00pm - 4:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545452036">
# <input class="durc" data-seq="12449108" id="sch545452036" name="sid[]" onchange="checkDur('545452036');" type="checkbox" value="545452036"/>
# 						4:00pm - 5:00pm
# 					  </label>
# </div><input id="sch545452036dur" name="dur545452036" type="hidden" value="60"/><input id="t_sch545452036" name="t_sch545452036" type="hidden" value="3N 4:00pm - 5:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545452037">
# <input class="durc" data-seq="12449109" id="sch545452037" name="sid[]" onchange="checkDur('545452037');" type="checkbox" value="545452037"/>
# 						5:00pm - 6:00pm
# 					  </label>
# </div><input id="sch545452037dur" name="dur545452037" type="hidden" value="60"/><input id="t_sch545452037" name="t_sch545452037" type="hidden" value="3N 5:00pm - 6:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545452038">
# <input class="durc" data-seq="12449110" id="sch545452038" name="sid[]" onchange="checkDur('545452038');" type="checkbox" value="545452038"/>
# 						6:00pm - 7:00pm
# 					  </label>
# </div><input id="sch545452038dur" name="dur545452038" type="hidden" value="60"/><input id="t_sch545452038" name="t_sch545452038" type="hidden" value="3N 6:00pm - 7:00pm Thursday, July 20, 2017"/><a class="sr-only" href="#bform">Skip to registration form</a></fieldset><fieldset class="s-lc-rm-cap-l-1"><legend><h2>3P <small>Capacity: 1</small></h2></legend><div>Group Study Room. Collab8 technology evaluation.</div><div class="checkbox">
# <label for="sch545452018">
# <input class="durc" data-seq="12450101" id="sch545452018" name="sid[]" onchange="checkDur('545452018');" type="checkbox" value="545452018"/>
# 						9:00am - 10:00am
# 					  </label>
# </div><input id="sch545452018dur" name="dur545452018" type="hidden" value="60"/><input id="t_sch545452018" name="t_sch545452018" type="hidden" value="3P 9:00am - 10:00am Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545452019">
# <input class="durc" data-seq="12450102" id="sch545452019" name="sid[]" onchange="checkDur('545452019');" type="checkbox" value="545452019"/>
# 						10:00am - 11:00am
# 					  </label>
# </div><input id="sch545452019dur" name="dur545452019" type="hidden" value="60"/><input id="t_sch545452019" name="t_sch545452019" type="hidden" value="3P 10:00am - 11:00am Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545452020">
# <input class="durc" data-seq="12450103" id="sch545452020" name="sid[]" onchange="checkDur('545452020');" type="checkbox" value="545452020"/>
# 						11:00am - 12:00pm
# 					  </label>
# </div><input id="sch545452020dur" name="dur545452020" type="hidden" value="60"/><input id="t_sch545452020" name="t_sch545452020" type="hidden" value="3P 11:00am - 12:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545452021">
# <input class="durc" data-seq="12450104" id="sch545452021" name="sid[]" onchange="checkDur('545452021');" type="checkbox" value="545452021"/>
# 						12:00pm - 1:00pm
# 					  </label>
# </div><input id="sch545452021dur" name="dur545452021" type="hidden" value="60"/><input id="t_sch545452021" name="t_sch545452021" type="hidden" value="3P 12:00pm - 1:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545452022">
# <input class="durc" data-seq="12450105" id="sch545452022" name="sid[]" onchange="checkDur('545452022');" type="checkbox" value="545452022"/>
# 						1:00pm - 2:00pm
# 					  </label>
# </div><input id="sch545452022dur" name="dur545452022" type="hidden" value="60"/><input id="t_sch545452022" name="t_sch545452022" type="hidden" value="3P 1:00pm - 2:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545452023">
# <input class="durc" data-seq="12450106" id="sch545452023" name="sid[]" onchange="checkDur('545452023');" type="checkbox" value="545452023"/>
# 						2:00pm - 3:00pm
# 					  </label>
# </div><input id="sch545452023dur" name="dur545452023" type="hidden" value="60"/><input id="t_sch545452023" name="t_sch545452023" type="hidden" value="3P 2:00pm - 3:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545452024">
# <input class="durc" data-seq="12450107" id="sch545452024" name="sid[]" onchange="checkDur('545452024');" type="checkbox" value="545452024"/>
# 						3:00pm - 4:00pm
# 					  </label>
# </div><input id="sch545452024dur" name="dur545452024" type="hidden" value="60"/><input id="t_sch545452024" name="t_sch545452024" type="hidden" value="3P 3:00pm - 4:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545452025">
# <input class="durc" data-seq="12450108" id="sch545452025" name="sid[]" onchange="checkDur('545452025');" type="checkbox" value="545452025"/>
# 						4:00pm - 5:00pm
# 					  </label>
# </div><input id="sch545452025dur" name="dur545452025" type="hidden" value="60"/><input id="t_sch545452025" name="t_sch545452025" type="hidden" value="3P 4:00pm - 5:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545452026">
# <input class="durc" data-seq="12450109" id="sch545452026" name="sid[]" onchange="checkDur('545452026');" type="checkbox" value="545452026"/>
# 						5:00pm - 6:00pm
# 					  </label>
# </div><input id="sch545452026dur" name="dur545452026" type="hidden" value="60"/><input id="t_sch545452026" name="t_sch545452026" type="hidden" value="3P 5:00pm - 6:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545452027">
# <input class="durc" data-seq="12450110" id="sch545452027" name="sid[]" onchange="checkDur('545452027');" type="checkbox" value="545452027"/>
# 						6:00pm - 7:00pm
# 					  </label>
# </div><input id="sch545452027dur" name="dur545452027" type="hidden" value="60"/><input id="t_sch545452027" name="t_sch545452027" type="hidden" value="3P 6:00pm - 7:00pm Thursday, July 20, 2017"/><a class="sr-only" href="#bform">Skip to registration form</a></fieldset><fieldset class="s-lc-rm-cap-l-1"><legend><h2>3Q <small>Capacity: 1</small></h2></legend><div>Group Study Room. Collab8 technology evaluation.</div><div class="checkbox">
# <label for="sch545452007">
# <input class="durc" data-seq="12451101" id="sch545452007" name="sid[]" onchange="checkDur('545452007');" type="checkbox" value="545452007"/>
# 						9:00am - 10:00am
# 					  </label>
# </div><input id="sch545452007dur" name="dur545452007" type="hidden" value="60"/><input id="t_sch545452007" name="t_sch545452007" type="hidden" value="3Q 9:00am - 10:00am Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545452008">
# <input class="durc" data-seq="12451102" id="sch545452008" name="sid[]" onchange="checkDur('545452008');" type="checkbox" value="545452008"/>
# 						10:00am - 11:00am
# 					  </label>
# </div><input id="sch545452008dur" name="dur545452008" type="hidden" value="60"/><input id="t_sch545452008" name="t_sch545452008" type="hidden" value="3Q 10:00am - 11:00am Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545452009">
# <input class="durc" data-seq="12451103" id="sch545452009" name="sid[]" onchange="checkDur('545452009');" type="checkbox" value="545452009"/>
# 						11:00am - 12:00pm
# 					  </label>
# </div><input id="sch545452009dur" name="dur545452009" type="hidden" value="60"/><input id="t_sch545452009" name="t_sch545452009" type="hidden" value="3Q 11:00am - 12:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545452010">
# <input class="durc" data-seq="12451104" id="sch545452010" name="sid[]" onchange="checkDur('545452010');" type="checkbox" value="545452010"/>
# 						12:00pm - 1:00pm
# 					  </label>
# </div><input id="sch545452010dur" name="dur545452010" type="hidden" value="60"/><input id="t_sch545452010" name="t_sch545452010" type="hidden" value="3Q 12:00pm - 1:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545452011">
# <input class="durc" data-seq="12451105" id="sch545452011" name="sid[]" onchange="checkDur('545452011');" type="checkbox" value="545452011"/>
# 						1:00pm - 2:00pm
# 					  </label>
# </div><input id="sch545452011dur" name="dur545452011" type="hidden" value="60"/><input id="t_sch545452011" name="t_sch545452011" type="hidden" value="3Q 1:00pm - 2:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545452012">
# <input class="durc" data-seq="12451106" id="sch545452012" name="sid[]" onchange="checkDur('545452012');" type="checkbox" value="545452012"/>
# 						2:00pm - 3:00pm
# 					  </label>
# </div><input id="sch545452012dur" name="dur545452012" type="hidden" value="60"/><input id="t_sch545452012" name="t_sch545452012" type="hidden" value="3Q 2:00pm - 3:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545452013">
# <input class="durc" data-seq="12451107" id="sch545452013" name="sid[]" onchange="checkDur('545452013');" type="checkbox" value="545452013"/>
# 						3:00pm - 4:00pm
# 					  </label>
# </div><input id="sch545452013dur" name="dur545452013" type="hidden" value="60"/><input id="t_sch545452013" name="t_sch545452013" type="hidden" value="3Q 3:00pm - 4:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545452014">
# <input class="durc" data-seq="12451108" id="sch545452014" name="sid[]" onchange="checkDur('545452014');" type="checkbox" value="545452014"/>
# 						4:00pm - 5:00pm
# 					  </label>
# </div><input id="sch545452014dur" name="dur545452014" type="hidden" value="60"/><input id="t_sch545452014" name="t_sch545452014" type="hidden" value="3Q 4:00pm - 5:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545452015">
# <input class="durc" data-seq="12451109" id="sch545452015" name="sid[]" onchange="checkDur('545452015');" type="checkbox" value="545452015"/>
# 						5:00pm - 6:00pm
# 					  </label>
# </div><input id="sch545452015dur" name="dur545452015" type="hidden" value="60"/><input id="t_sch545452015" name="t_sch545452015" type="hidden" value="3Q 5:00pm - 6:00pm Thursday, July 20, 2017"/><div class="checkbox">
# <label for="sch545452016">
# <input class="durc" data-seq="12451110" id="sch545452016" name="sid[]" onchange="checkDur('545452016');" type="checkbox" value="545452016"/>
# 						6:00pm - 7:00pm
# 					  </label>
# </div><input id="sch545452016dur" name="dur545452016" type="hidden" value="60"/><input id="t_sch545452016" name="t_sch545452016" type="hidden" value="3Q 6:00pm - 7:00pm Thursday, July 20, 2017"/><a class="sr-only" href="#bform">Skip to registration form</a></fieldset><div class="s-lc-rm-box" id="s-lc-rm-tc-box"><p>Groups have priority. If you make a reservation as an individual, a group may ask you to relocate.<em>(Except for the MMPL iMac Workstations)</em></p>
# <p>Each reservation has a 10 minute grace period. If your group has not arrived after the first 10 minutes of your reservation have passed, another group may take over your reservation.<em></em></p>
# <p><span style="font-size: small;"><strong><span style="font-size: x-small;">NOTE: If furniture or equipment is lost or damaged while you are in the room, you may be charged for repair or replacement.</span><br/></strong></span></p>
# <p><span style="font-size: small;"><strong> </strong></span></p></div><fieldset><legend><h2 id="bform" tabindex="0">Booking Details</h2></legend><div class="form-group">
# <div class="col-sm-12"><p class="pull-right text-muted" id="s-lc-rm-req-text">* Required Field</p></div>
# </div>
# <div class="form-group s-lc-rm-q s-lc-name">
# <strong class="col-sm-3 control-label">Full Name *</strong>
# <div class="col-sm-4">
# <label class="sr-only" for="fname">First Name</label>
# <input aria-required="true" class="form-control" id="fname" name="fname" placeholder="First Name" title="First Name" type="text"/>
# </div>
# <div class="col-sm-5">
# <label class="sr-only" for="lname">Last Name</label>
# <input aria-required="true" class="form-control" id="lname" name="lname" placeholder="Last Name" title="Last Name" type="text"/>
# </div>
# </div>
# <div class="form-group s-lc-rm-q s-lc-email">
# <label class="col-sm-3 control-label" for="email">Email *</label>
# <div class="col-sm-9">
# <input aria-required="true" class="form-control" id="email" name="email" type="email"/>
# 										Enter @usc.edu addresses only
# 									</div>
# </div><input name="qcount" type="hidden" value="0"/>
# <input name="fid" type="hidden" value="0"/><div class="form-group">
# <div class="col-sm-offset-3 col-sm-9">
# <button class="btn btn-primary" id="s-lc-rm-ac-but" onclick="return bookRoom();" type="submit">Submit my Booking</button>
# </div>
# </div></fieldset>
# </form>

# %%
a='abc123'
int(''.join(list(filter(str.isdigit, a))))
# Out:
# 123

# %%
items = book_room_form.findAll('input',value='60',type='hidden')

# %%
for i in items:
#     print(i.next_sibling)
    if '3F 9:00am -' in i.next_sibling['value']:
        print('y')
# Out:
# y

# %%
params = list()
i = 2
for item in items:
    params.append((item['name'], 60))
    item_content = item.next_sibling
#     print(item_content)
#     print(item_content['name'])
    params.append((item_content['name'],item_content['value']))
    if i:
        params.append(('sid[]',int(''.join(list(filter(str.isdigit, item['name']))))))
        i -= 1
        print('time')
# Out:
# time
# time

# %%
params.append(('gid',4490))
params.append(('fname','test'))
params.append(('lname','test'))
params.append(('email','test@usc.edu'))
params.append(('qcount',0))
params.append(('fid',0))

# %%
params.append(('gid',4490))
params['fname']='test'
params['lname']='test'
params['email']='test@usc.edu'
params['qcount'] = 0
params['fid'] = 0

# %%
a =0
if a:
    print (1)

# %%
params
# Out:
# [('dur545446947', 60),
#  ('t_sch545446947', '3F 9:00am - 10:00am Tuesday, July 25, 2017'),
#  ('sid[]', 545446947),
#  ('dur545446948', 60),
#  ('t_sch545446948', '3F 10:00am - 11:00am Tuesday, July 25, 2017'),
#  ('sid[]', 545446948),
#  ('dur545446949', 60),
#  ('t_sch545446949', '3F 11:00am - 12:00pm Tuesday, July 25, 2017'),
#  ('dur545446951', 60),
#  ('t_sch545446951', '3F 1:00pm - 2:00pm Tuesday, July 25, 2017'),
#  ('dur545446952', 60),
#  ('t_sch545446952', '3F 2:00pm - 3:00pm Tuesday, July 25, 2017'),
#  ('dur545446953', 60),
#  ('t_sch545446953', '3F 3:00pm - 4:00pm Tuesday, July 25, 2017'),
#  ('dur545446954', 60),
#  ('t_sch545446954', '3F 4:00pm - 5:00pm Tuesday, July 25, 2017'),
#  ('dur545446955', 60),
#  ('t_sch545446955', '3F 5:00pm - 6:00pm Tuesday, July 25, 2017'),
#  ('dur545446956', 60),
#  ('t_sch545446956', '3F 6:00pm - 7:00pm Tuesday, July 25, 2017'),
#  ('dur545446936', 60),
#  ('t_sch545446936', '3G 9:00am - 10:00am Tuesday, July 25, 2017'),
#  ('dur545446937', 60),
#  ('t_sch545446937', '3G 10:00am - 11:00am Tuesday, July 25, 2017'),
#  ('dur545446938', 60),
#  ('t_sch545446938', '3G 11:00am - 12:00pm Tuesday, July 25, 2017'),
#  ('dur545446939', 60),
#  ('t_sch545446939', '3G 12:00pm - 1:00pm Tuesday, July 25, 2017'),
#  ('dur545446940', 60),
#  ('t_sch545446940', '3G 1:00pm - 2:00pm Tuesday, July 25, 2017'),
#  ('dur545446941', 60),
#  ('t_sch545446941', '3G 2:00pm - 3:00pm Tuesday, July 25, 2017'),
#  ('dur545446942', 60),
#  ('t_sch545446942', '3G 3:00pm - 4:00pm Tuesday, July 25, 2017'),
#  ('dur545446943', 60),
#  ('t_sch545446943', '3G 4:00pm - 5:00pm Tuesday, July 25, 2017'),
#  ('dur545446944', 60),
#  ('t_sch545446944', '3G 5:00pm - 6:00pm Tuesday, July 25, 2017'),
#  ('dur545446945', 60),
#  ('t_sch545446945', '3G 6:00pm - 7:00pm Tuesday, July 25, 2017'),
#  ('dur545446925', 60),
#  ('t_sch545446925', '3H 9:00am - 10:00am Tuesday, July 25, 2017'),
#  ('dur545446926', 60),
#  ('t_sch545446926', '3H 10:00am - 11:00am Tuesday, July 25, 2017'),
#  ('dur545446927', 60),
#  ('t_sch545446927', '3H 11:00am - 12:00pm Tuesday, July 25, 2017'),
#  ('dur545446928', 60),
#  ('t_sch545446928', '3H 12:00pm - 1:00pm Tuesday, July 25, 2017'),
#  ('dur545446929', 60),
#  ('t_sch545446929', '3H 1:00pm - 2:00pm Tuesday, July 25, 2017'),
#  ('dur545446930', 60),
#  ('t_sch545446930', '3H 2:00pm - 3:00pm Tuesday, July 25, 2017'),
#  ('dur545446931', 60),
#  ('t_sch545446931', '3H 3:00pm - 4:00pm Tuesday, July 25, 2017'),
#  ('dur545446932', 60),
#  ('t_sch545446932', '3H 4:00pm - 5:00pm Tuesday, July 25, 2017'),
#  ('dur545446933', 60),
#  ('t_sch545446933', '3H 5:00pm - 6:00pm Tuesday, July 25, 2017'),
#  ('dur545446934', 60),
#  ('t_sch545446934', '3H 6:00pm - 7:00pm Tuesday, July 25, 2017'),
#  ('dur545446914', 60),
#  ('t_sch545446914', '3J 9:00am - 10:00am Tuesday, July 25, 2017'),
#  ('dur545446915', 60),
#  ('t_sch545446915', '3J 10:00am - 11:00am Tuesday, July 25, 2017'),
#  ('dur545446916', 60),
#  ('t_sch545446916', '3J 11:00am - 12:00pm Tuesday, July 25, 2017'),
#  ('dur545446917', 60),
#  ('t_sch545446917', '3J 12:00pm - 1:00pm Tuesday, July 25, 2017'),
#  ('dur545446918', 60),
#  ('t_sch545446918', '3J 1:00pm - 2:00pm Tuesday, July 25, 2017'),
#  ('dur545446919', 60),
#  ('t_sch545446919', '3J 2:00pm - 3:00pm Tuesday, July 25, 2017'),
#  ('dur545446920', 60),
#  ('t_sch545446920', '3J 3:00pm - 4:00pm Tuesday, July 25, 2017'),
#  ('dur545446921', 60),
#  ('t_sch545446921', '3J 4:00pm - 5:00pm Tuesday, July 25, 2017'),
#  ('dur545446922', 60),
#  ('t_sch545446922', '3J 5:00pm - 6:00pm Tuesday, July 25, 2017'),
#  ('dur545446923', 60),
#  ('t_sch545446923', '3J 6:00pm - 7:00pm Tuesday, July 25, 2017'),
#  ('dur545446903', 60),
#  ('t_sch545446903', '3R 9:00am - 10:00am Tuesday, July 25, 2017'),
#  ('dur545446904', 60),
#  ('t_sch545446904', '3R 10:00am - 11:00am Tuesday, July 25, 2017'),
#  ('dur545446905', 60),
#  ('t_sch545446905', '3R 11:00am - 12:00pm Tuesday, July 25, 2017'),
#  ('dur545446906', 60),
#  ('t_sch545446906', '3R 12:00pm - 1:00pm Tuesday, July 25, 2017'),
#  ('dur545446907', 60),
#  ('t_sch545446907', '3R 1:00pm - 2:00pm Tuesday, July 25, 2017'),
#  ('dur545446908', 60),
#  ('t_sch545446908', '3R 2:00pm - 3:00pm Tuesday, July 25, 2017'),
#  ('dur545446909', 60),
#  ('t_sch545446909', '3R 3:00pm - 4:00pm Tuesday, July 25, 2017'),
#  ('dur545446910', 60),
#  ('t_sch545446910', '3R 4:00pm - 5:00pm Tuesday, July 25, 2017'),
#  ('dur545446911', 60),
#  ('t_sch545446911', '3R 5:00pm - 6:00pm Tuesday, July 25, 2017'),
#  ('dur545446912', 60),
#  ('t_sch545446912', '3R 6:00pm - 7:00pm Tuesday, July 25, 2017'),
#  ('dur545446892', 60),
#  ('t_sch545446892', '3S 9:00am - 10:00am Tuesday, July 25, 2017'),
#  ('dur545446893', 60),
#  ('t_sch545446893', '3S 10:00am - 11:00am Tuesday, July 25, 2017'),
#  ('dur545446894', 60),
#  ('t_sch545446894', '3S 11:00am - 12:00pm Tuesday, July 25, 2017'),
#  ('dur545446895', 60),
#  ('t_sch545446895', '3S 12:00pm - 1:00pm Tuesday, July 25, 2017'),
#  ('dur545446896', 60),
#  ('t_sch545446896', '3S 1:00pm - 2:00pm Tuesday, July 25, 2017'),
#  ('dur545446897', 60),
#  ('t_sch545446897', '3S 2:00pm - 3:00pm Tuesday, July 25, 2017'),
#  ('dur545446898', 60),
#  ('t_sch545446898', '3S 3:00pm - 4:00pm Tuesday, July 25, 2017'),
#  ('dur545446899', 60),
#  ('t_sch545446899', '3S 4:00pm - 5:00pm Tuesday, July 25, 2017'),
#  ('dur545446900', 60),
#  ('t_sch545446900', '3S 5:00pm - 6:00pm Tuesday, July 25, 2017'),
#  ('dur545446901', 60),
#  ('t_sch545446901', '3S 6:00pm - 7:00pm Tuesday, July 25, 2017'),
#  ('dur545446881', 60),
#  ('t_sch545446881', '3T 9:00am - 10:00am Tuesday, July 25, 2017'),
#  ('dur545446882', 60),
#  ('t_sch545446882', '3T 10:00am - 11:00am Tuesday, July 25, 2017'),
#  ('dur545446883', 60),
#  ('t_sch545446883', '3T 11:00am - 12:00pm Tuesday, July 25, 2017'),
#  ('dur545446884', 60),
#  ('t_sch545446884', '3T 12:00pm - 1:00pm Tuesday, July 25, 2017'),
#  ('dur545446885', 60),
#  ('t_sch545446885', '3T 1:00pm - 2:00pm Tuesday, July 25, 2017'),
#  ('dur545446886', 60),
#  ('t_sch545446886', '3T 2:00pm - 3:00pm Tuesday, July 25, 2017'),
#  ('dur545446887', 60),
#  ('t_sch545446887', '3T 3:00pm - 4:00pm Tuesday, July 25, 2017'),
#  ('dur545446888', 60),
#  ('t_sch545446888', '3T 4:00pm - 5:00pm Tuesday, July 25, 2017'),
#  ('dur545446889', 60),
#  ('t_sch545446889', '3T 5:00pm - 6:00pm Tuesday, July 25, 2017'),
#  ('dur545446890', 60),
#  ('t_sch545446890', '3T 6:00pm - 7:00pm Tuesday, July 25, 2017'),
#  ('dur545446870', 60),
#  ('t_sch545446870', '3U 9:00am - 10:00am Tuesday, July 25, 2017'),
#  ('dur545446871', 60),
#  ('t_sch545446871', '3U 10:00am - 11:00am Tuesday, July 25, 2017'),
#  ('dur545446872', 60),
#  ('t_sch545446872', '3U 11:00am - 12:00pm Tuesday, July 25, 2017'),
#  ('dur545446873', 60),
#  ('t_sch545446873', '3U 12:00pm - 1:00pm Tuesday, July 25, 2017'),
#  ('dur545446874', 60),
#  ('t_sch545446874', '3U 1:00pm - 2:00pm Tuesday, July 25, 2017'),
#  ('dur545446875', 60),
#  ('t_sch545446875', '3U 2:00pm - 3:00pm Tuesday, July 25, 2017'),
#  ('dur545446876', 60),
#  ('t_sch545446876', '3U 3:00pm - 4:00pm Tuesday, July 25, 2017'),
#  ('dur545446877', 60),
#  ('t_sch545446877', '3U 4:00pm - 5:00pm Tuesday, July 25, 2017'),
#  ('dur545446878', 60),
#  ('t_sch545446878', '3U 5:00pm - 6:00pm Tuesday, July 25, 2017'),
#  ('dur545446879', 60),
#  ('t_sch545446879', '3U 6:00pm - 7:00pm Tuesday, July 25, 2017'),
#  ('dur545446859', 60),
#  ('t_sch545446859', '3W 9:00am - 10:00am Tuesday, July 25, 2017'),
#  ('dur545446860', 60),
#  ('t_sch545446860', '3W 10:00am - 11:00am Tuesday, July 25, 2017'),
#  ('dur545446861', 60),
#  ('t_sch545446861', '3W 11:00am - 12:00pm Tuesday, July 25, 2017'),
#  ('dur545446862', 60),
#  ('t_sch545446862', '3W 12:00pm - 1:00pm Tuesday, July 25, 2017'),
#  ('dur545446863', 60),
#  ('t_sch545446863', '3W 1:00pm - 2:00pm Tuesday, July 25, 2017'),
#  ('dur545446864', 60),
#  ('t_sch545446864', '3W 2:00pm - 3:00pm Tuesday, July 25, 2017'),
#  ('dur545446865', 60),
#  ('t_sch545446865', '3W 3:00pm - 4:00pm Tuesday, July 25, 2017'),
#  ('dur545446866', 60),
#  ('t_sch545446866', '3W 4:00pm - 5:00pm Tuesday, July 25, 2017'),
#  ('dur545446867', 60),
#  ('t_sch545446867', '3W 5:00pm - 6:00pm Tuesday, July 25, 2017'),
#  ('dur545446868', 60),
#  ('t_sch545446868', '3W 6:00pm - 7:00pm Tuesday, July 25, 2017'),
#  ('dur545446848', 60),
#  ('t_sch545446848', '3X 9:00am - 10:00am Tuesday, July 25, 2017'),
#  ('dur545446849', 60),
#  ('t_sch545446849', '3X 10:00am - 11:00am Tuesday, July 25, 2017'),
#  ('dur545446850', 60),
#  ('t_sch545446850', '3X 11:00am - 12:00pm Tuesday, July 25, 2017'),
#  ('dur545446851', 60),
#  ('t_sch545446851', '3X 12:00pm - 1:00pm Tuesday, July 25, 2017'),
#  ('dur545446852', 60),
#  ('t_sch545446852', '3X 1:00pm - 2:00pm Tuesday, July 25, 2017'),
#  ('dur545446853', 60),
#  ('t_sch545446853', '3X 2:00pm - 3:00pm Tuesday, July 25, 2017'),
#  ('dur545446854', 60),
#  ('t_sch545446854', '3X 3:00pm - 4:00pm Tuesday, July 25, 2017'),
#  ('dur545446855', 60),
#  ('t_sch545446855', '3X 4:00pm - 5:00pm Tuesday, July 25, 2017'),
#  ('dur545446856', 60),
#  ('t_sch545446856', '3X 5:00pm - 6:00pm Tuesday, July 25, 2017'),
#  ('dur545446857', 60),
#  ('t_sch545446857', '3X 6:00pm - 7:00pm Tuesday, July 25, 2017'),
#  ('dur545447013', 60),
#  ('t_sch545447013', '3AA 9:00am - 10:00am Tuesday, July 25, 2017'),
#  ('dur545447014', 60),
#  ('t_sch545447014', '3AA 10:00am - 11:00am Tuesday, July 25, 2017'),
#  ('dur545447015', 60),
#  ('t_sch545447015', '3AA 11:00am - 12:00pm Tuesday, July 25, 2017'),
#  ('dur545447016', 60),
#  ('t_sch545447016', '3AA 12:00pm - 1:00pm Tuesday, July 25, 2017'),
#  ('dur545447017', 60),
#  ('t_sch545447017', '3AA 1:00pm - 2:00pm Tuesday, July 25, 2017'),
#  ('dur545447018', 60),
#  ('t_sch545447018', '3AA 2:00pm - 3:00pm Tuesday, July 25, 2017'),
#  ('dur545447019', 60),
#  ('t_sch545447019', '3AA 3:00pm - 4:00pm Tuesday, July 25, 2017'),
#  ('dur545447020', 60),
#  ('t_sch545447020', '3AA 4:00pm - 5:00pm Tuesday, July 25, 2017'),
#  ('dur545447021', 60),
#  ('t_sch545447021', '3AA 5:00pm - 6:00pm Tuesday, July 25, 2017'),
#  ('dur545447022', 60),
#  ('t_sch545447022', '3AA 6:00pm - 7:00pm Tuesday, July 25, 2017'),
#  ('dur545446837', 60),
#  ('t_sch545446837', '3K 9:00am - 10:00am Tuesday, July 25, 2017'),
#  ('dur545446838', 60),
#  ('t_sch545446838', '3K 10:00am - 11:00am Tuesday, July 25, 2017'),
#  ('dur545446839', 60),
#  ('t_sch545446839', '3K 11:00am - 12:00pm Tuesday, July 25, 2017'),
#  ('dur545446840', 60),
#  ('t_sch545446840', '3K 12:00pm - 1:00pm Tuesday, July 25, 2017'),
#  ('dur545446841', 60),
#  ('t_sch545446841', '3K 1:00pm - 2:00pm Tuesday, July 25, 2017'),
#  ('dur545446842', 60),
#  ('t_sch545446842', '3K 2:00pm - 3:00pm Tuesday, July 25, 2017'),
#  ('dur545446843', 60),
#  ('t_sch545446843', '3K 3:00pm - 4:00pm Tuesday, July 25, 2017'),
#  ('dur545446844', 60),
#  ('t_sch545446844', '3K 4:00pm - 5:00pm Tuesday, July 25, 2017'),
#  ('dur545446845', 60),
#  ('t_sch545446845', '3K 5:00pm - 6:00pm Tuesday, July 25, 2017'),
#  ('dur545446846', 60),
#  ('t_sch545446846', '3K 6:00pm - 7:00pm Tuesday, July 25, 2017'),
#  ('dur545447002', 60),
#  ('t_sch545447002', '3L 9:00am - 10:00am Tuesday, July 25, 2017'),
#  ('dur545447003', 60),
#  ('t_sch545447003', '3L 10:00am - 11:00am Tuesday, July 25, 2017'),
#  ('dur545447004', 60),
#  ('t_sch545447004', '3L 11:00am - 12:00pm Tuesday, July 25, 2017'),
#  ('dur545447005', 60),
#  ('t_sch545447005', '3L 12:00pm - 1:00pm Tuesday, July 25, 2017'),
#  ('dur545447006', 60),
#  ('t_sch545447006', '3L 1:00pm - 2:00pm Tuesday, July 25, 2017'),
#  ('dur545447007', 60),
#  ('t_sch545447007', '3L 2:00pm - 3:00pm Tuesday, July 25, 2017'),
#  ('dur545447008', 60),
#  ('t_sch545447008', '3L 3:00pm - 4:00pm Tuesday, July 25, 2017'),
#  ('dur545447009', 60),
#  ('t_sch545447009', '3L 4:00pm - 5:00pm Tuesday, July 25, 2017'),
#  ('dur545447010', 60),
#  ('t_sch545447010', '3L 5:00pm - 6:00pm Tuesday, July 25, 2017'),
#  ('dur545447011', 60),
#  ('t_sch545447011', '3L 6:00pm - 7:00pm Tuesday, July 25, 2017'),
#  ('dur545446980', 60),
#  ('t_sch545446980', '3N 9:00am - 10:00am Tuesday, July 25, 2017'),
#  ('dur545446981', 60),
#  ('t_sch545446981', '3N 10:00am - 11:00am Tuesday, July 25, 2017'),
#  ('dur545446982', 60),
#  ('t_sch545446982', '3N 11:00am - 12:00pm Tuesday, July 25, 2017'),
#  ('dur545446983', 60),
#  ('t_sch545446983', '3N 12:00pm - 1:00pm Tuesday, July 25, 2017'),
#  ('dur545446984', 60),
#  ('t_sch545446984', '3N 1:00pm - 2:00pm Tuesday, July 25, 2017'),
#  ('dur545446985', 60),
#  ('t_sch545446985', '3N 2:00pm - 3:00pm Tuesday, July 25, 2017'),
#  ('dur545446986', 60),
#  ('t_sch545446986', '3N 3:00pm - 4:00pm Tuesday, July 25, 2017'),
#  ('dur545446987', 60),
#  ('t_sch545446987', '3N 4:00pm - 5:00pm Tuesday, July 25, 2017'),
#  ('dur545446988', 60),
#  ('t_sch545446988', '3N 5:00pm - 6:00pm Tuesday, July 25, 2017'),
#  ('dur545446989', 60),
#  ('t_sch545446989', '3N 6:00pm - 7:00pm Tuesday, July 25, 2017'),
#  ('dur545446969', 60),
#  ('t_sch545446969', '3P 9:00am - 10:00am Tuesday, July 25, 2017'),
#  ('dur545446970', 60),
#  ('t_sch545446970', '3P 10:00am - 11:00am Tuesday, July 25, 2017'),
#  ('dur545446971', 60),
#  ('t_sch545446971', '3P 11:00am - 12:00pm Tuesday, July 25, 2017'),
#  ('dur545446972', 60),
#  ('t_sch545446972', '3P 12:00pm - 1:00pm Tuesday, July 25, 2017'),
#  ('dur545446973', 60),
#  ('t_sch545446973', '3P 1:00pm - 2:00pm Tuesday, July 25, 2017'),
#  ('dur545446974', 60),
#  ('t_sch545446974', '3P 2:00pm - 3:00pm Tuesday, July 25, 2017'),
#  ('dur545446975', 60),
#  ('t_sch545446975', '3P 3:00pm - 4:00pm Tuesday, July 25, 2017'),
#  ('dur545446976', 60),
#  ('t_sch545446976', '3P 4:00pm - 5:00pm Tuesday, July 25, 2017'),
#  ('dur545446977', 60),
#  ('t_sch545446977', '3P 5:00pm - 6:00pm Tuesday, July 25, 2017'),
#  ('dur545446978', 60),
#  ('t_sch545446978', '3P 6:00pm - 7:00pm Tuesday, July 25, 2017'),
#  ('dur545446958', 60),
#  ('t_sch545446958', '3Q 9:00am - 10:00am Tuesday, July 25, 2017'),
#  ('dur545446959', 60),
#  ('t_sch545446959', '3Q 10:00am - 11:00am Tuesday, July 25, 2017'),
#  ('dur545446960', 60),
#  ('t_sch545446960', '3Q 11:00am - 12:00pm Tuesday, July 25, 2017'),
#  ('dur545446961', 60),
#  ('t_sch545446961', '3Q 12:00pm - 1:00pm Tuesday, July 25, 2017'),
#  ('dur545446962', 60),
#  ('t_sch545446962', '3Q 1:00pm - 2:00pm Tuesday, July 25, 2017'),
#  ('dur545446963', 60),
#  ('t_sch545446963', '3Q 2:00pm - 3:00pm Tuesday, July 25, 2017'),
#  ('dur545446964', 60),
#  ('t_sch545446964', '3Q 3:00pm - 4:00pm Tuesday, July 25, 2017'),
#  ('dur545446965', 60),
#  ('t_sch545446965', '3Q 4:00pm - 5:00pm Tuesday, July 25, 2017'),
#  ('dur545446966', 60),
#  ('t_sch545446966', '3Q 5:00pm - 6:00pm Tuesday, July 25, 2017'),
#  ('dur545446967', 60),
#  ('t_sch545446967', '3Q 6:00pm - 7:00pm Tuesday, July 25, 2017'),
#  ('gid', 4490),
#  ('fname', 'test'),
#  ('lname', 'test'),
#  ('email', 'test@usc.edu'),
#  ('qcount', 0),
#  ('fid', 0)]

# %%
import urllib.parse

# %%
post_data = urllib.parse.urlencode(params)

# %%
'Cookie':"_vwo_uuid_v2=641003E722BA383572EB5960C60479AE|1b62e9dc5791b7d2b6bcad3650c57fac; optimizelyEndUserId=oeu1479493308140r0.28413408277979224; optimizelySegments=%7B%224150957310%22%3A%22false%22%2C%224155974626%22%3A%22search%22%2C%224163194645%22%3A%22gc%22%7D; optimizelyBuckets=%7B%7D; desktopCookie=uschomepage; __utma=185748653.185138458.1479232294.1485728281.1485735202.4; __utmz=185748653.1485735202.4.4.utmcsr=google|utmccn=(organic)|utmcmd=organic|utmctr=(not%20provided); __hstc=77507402.c99caa907c017d0cd093ec68a08585ce.1485740385320.1485740385320.1485740385320.1; hsfirstvisit=http%3A%2F%2Fexechealthadmin.usc.edu%2Fadmissions|http%3A%2F%2Fwww.bing.com%2Fsearch%3Fq%3Dusc%2520price%2520online%2520requirements%26qs%3Dn%26form%3DQBRE%26sp%3D-1%26pq%3Dusc%2520price%2520online%2520requirements%26sc%3D0-29%26sk%3D%26cvid%3D2AF353EB7C944C87865EBC99354240E1|1485740385314; hubspotutk=c99caa907c017d0cd093ec68a08585ce; __unam=79ac26c-1586b64794e-4522b679-162; AWSALB=58uIzcz0XzBXpuCiCHR3FJ8AJOP4fzrL9GNWKK0mVSKCoeL9nZPTs8j1qbAzLQHRNf0XEaERmQKPnrjkwMF3xTy5CR1BMmQdohJsN6fxAcB/OGP6/z2q5qvGH2k4; lc_rbv=a%3A1%3A%7Bs%3A44%3A%22XgUHld%2FQ8a79ioW5IKe%2F8C%2FTGJ3UD8%2FoXPchDn2mskc%3D%22%3Bs%3A128%3A%22TuQhnrxLREHysEVsmN4sjbYHPjywTucoK3YC9mf%2FBDuOZ4H%2BJWzh%2BqlDNMjM8jaK2efOrAbo6ttZKThjBw9jWg%2Fc0OXfF%2B8pT5dtGEbh33SjNAKJI%2BDUmg150302U%2F9g%22%3B%7D; _ga=GA1.2.185138458.1479232294; _gid=GA1.2.1893662304.1500247444"

# %%
url = 'http://libcal.usc.edu/process_roombookings.php?m=booking_mob'
headers = {
'Content-Type':'application/x-www-form-urlencoded; charset=UTF-8',
'Host':'libcal.usc.edu',
'Connection':'keep-alive',
'Accept':"application/json, text/javascript, */*; q=0.01",
'Origin':'http://libcal.usc.edu',
'X-Requested-With':'XMLHttpRequest',
'User-Agent':'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/59.0.3071.115 Mobile Safari/537.36',
'Referer':'http://libcal.usc.edu/booking/its',
'Accept-Encoding':'gzip, deflate',
'Accept-Language':'en,zh-CN;q=0.8,zh;q=0.6',      
'Cookie':"_vwo_uuid_v2=641003E722BA383572EB5960C60479AE|1b62e9dc5791b7d2b6bcad3650c57fac; optimizelyEndUserId=oeu1479493308140r0.28413408277979224; optimizelySegments=%7B%224150957310%22%3A%22false%22%2C%224155974626%22%3A%22search%22%2C%224163194645%22%3A%22gc%22%7D; optimizelyBuckets=%7B%7D; desktopCookie=uschomepage; __utma=185748653.185138458.1479232294.1485728281.1485735202.4; __utmz=185748653.1485735202.4.4.utmcsr=google|utmccn=(organic)|utmcmd=organic|utmctr=(not%20provided); __hstc=77507402.c99caa907c017d0cd093ec68a08585ce.1485740385320.1485740385320.1485740385320.1; hsfirstvisit=http%3A%2F%2Fexechealthadmin.usc.edu%2Fadmissions|http%3A%2F%2Fwww.bing.com%2Fsearch%3Fq%3Dusc%2520price%2520online%2520requirements%26qs%3Dn%26form%3DQBRE%26sp%3D-1%26pq%3Dusc%2520price%2520online%2520requirements%26sc%3D0-29%26sk%3D%26cvid%3D2AF353EB7C944C87865EBC99354240E1|1485740385314; hubspotutk=c99caa907c017d0cd093ec68a08585ce; __unam=79ac26c-1586b64794e-4522b679-162; AWSALB=58uIzcz0XzBXpuCiCHR3FJ8AJOP4fzrL9GNWKK0mVSKCoeL9nZPTs8j1qbAzLQHRNf0XEaERmQKPnrjkwMF3xTy5CR1BMmQdohJsN6fxAcB/OGP6/z2q5qvGH2k4; lc_rbv=a%3A1%3A%7Bs%3A44%3A%22XgUHld%2FQ8a79ioW5IKe%2F8C%2FTGJ3UD8%2FoXPchDn2mskc%3D%22%3Bs%3A128%3A%22TuQhnrxLREHysEVsmN4sjbYHPjywTucoK3YC9mf%2FBDuOZ4H%2BJWzh%2BqlDNMjM8jaK2efOrAbo6ttZKThjBw9jWg%2Fc0OXfF%2B8pT5dtGEbh33SjNAKJI%2BDUmg150302U%2F9g%22%3B%7D; _ga=GA1.2.185138458.1479232294; _gid=GA1.2.1893662304.1500247444"
}
data = requests.post(url, data=post_data,headers=headers)

# %%
text = BeautifulSoup(data.json()['msg'],'lxml')
text.text
# Out:
# 'This booking is tentative only!3F, 9:00am - 10:00am Tuesday, July 25, 2017 - Tentative3F, 10:00am - 11:00am Tuesday, July 25, 2017 - TentativeYou must confirm the booking within 30 minutes,  via the URL contained in the email just sent to you.'

# %%
import requests
import datetime, time

# %%
'POST /process_roombookings.php?m=calscroll&gid=4490&date=2017-07-24&nocache=1500489933078 HTTP/1.1:',
'Cookie':'_vwo_uuid_v2=641003E722BA383572EB5960C60479AE|1b62e9dc5791b7d2b6bcad3650c57fac; optimizelyEndUserId=oeu1479493308140r0.28413408277979224; optimizelySegments=%7B%224150957310%22%3A%22false%22%2C%224155974626%22%3A%22search%22%2C%224163194645%22%3A%22gc%22%7D; optimizelyBuckets=%7B%7D; desktopCookie=uschomepage; __utma=185748653.185138458.1479232294.1485728281.1485735202.4; __utmz=185748653.1485735202.4.4.utmcsr=google|utmccn=(organic)|utmcmd=organic|utmctr=(not%20provided); __hstc=77507402.c99caa907c017d0cd093ec68a08585ce.1485740385320.1485740385320.1485740385320.1; hsfirstvisit=http%3A%2F%2Fexechealthadmin.usc.edu%2Fadmissions|http%3A%2F%2Fwww.bing.com%2Fsearch%3Fq%3Dusc%2520price%2520online%2520requirements%26qs%3Dn%26form%3DQBRE%26sp%3D-1%26pq%3Dusc%2520price%2520online%2520requirements%26sc%3D0-29%26sk%3D%26cvid%3D2AF353EB7C944C87865EBC99354240E1|1485740385314; hubspotutk=c99caa907c017d0cd093ec68a08585ce; __unam=79ac26c-1586b64794e-4522b679-162; lc_rbv=a%3A1%3A%7Bs%3A44%3A%22XgUHld%2FQ8a79ioW5IKe%2F8C%2FTGJ3UD8%2FoXPchDn2mskc%3D%22%3Bs%3A128%3A%22lrmyuo8M%2BXt1tjzkWEVnsA%2BVM4KvJeePSV%2BFkpqmgqufjC1J%2FVjN2KIuBB9elfcjqym1CWGFT1J9Dg5ftYhWrULFjAIL%2BTj6nAYggybMTgeeqISv%2BbRSSQI3MLp4Whdt%22%3B%7D; _ga=GA1.2.185138458.1479232294; _gid=GA1.2.1893662304.1500247444; _gat=1; AWSALB=Uz+R0PMgEnorshlAvYmmq3+OBYbxE2t3B4u+L+63BhOLtf1EqfRn8zPUSvb+zuBPIEev93UpIGzelyOBvYFN0RjkaRP9G9ACYEcemeJtykiJTC/6uMWRH8LiBetk',

# %%
url = 'http://libcal.usc.edu/process_roombookings.php?m=calscroll&gid=4490&date=2017-07-25&nocache='
nocache = int(time.time()*1000)
headers = {
'Host':'libcal.usc.edu',
'Connection':'keep-alive',
'Content-Length':'0',
'Accept':"*/*",
'Origin':'http://libcal.usc.edu',
'X-Requested-With':'XMLHttpRequest',
'User-Agent':'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/59.0.3071.115 Mobile Safari/537.36',
'Referer':'http://libcal.usc.edu/booking/its',
'Accept-Encoding':'gzip, deflate',
'Accept-Language':'en,zh-CN;q=0.8,zh;q=0.6',
        }

# %%
response = requests.post(url, headers = headers)

# %%
response.text
# Out:
# '<div id="s-lc-rm-tg-cont" class="s-lc-rm-box " tabindex="0"><table id="s-lc-rm-tg-tb" cellpadding="0" cellspacing="1">\n\t\t\t<tr><th colspan="2"><h3 id="s-lc-rm-tg-h">Tuesday, July 25, 2017</h3></th></tr>\n\t\t\t<tr>\n\t\t\t\t<!--left names col -->\n\t\t\t\t<td valign="top">\n\t\t\t\t\t<table cellpadding="0" cellspacing="1" id="s-lc-rm-tg-rnames">\n\t\t\t\t\t\t<tr><td>&nbsp;</td><td>&nbsp;</td></tr>\n\t\t\t\t\t\t<tr class="s-lc-rm-cap-l-1"><td class="s-lc-rm-rntd"><div class="s-lc-rm-rn">3F&nbsp;</div></td><td><div class="s-lc-rm-ttip"><i class="fa fa-info-circle s-lc-rm-pop" tabindex="0" role="button" data-toggle="popover" data-placement="right" data-html="true" data-trigger="click hover"\n\t\t\tdata-title="3F  <span class=\'s-lc-rm-cap-d\'> - </span><span class=\'s-lc-rm-cap-po\'>Capacity: 1.</span></small> " data-content=\'<div class="room_desc">Group Study Room</div>\'></i></div></td></tr><tr class="s-lc-rm-cap-l-1"><td class="s-lc-rm-rntd"><div class="s-lc-rm-rn">3G&nbsp;</div></td><td><div class="s-lc-rm-ttip"><i class="fa fa-info-circle s-lc-rm-pop" tabindex="0" role="button" data-toggle="popover" data-placement="right" data-html="true" data-trigger="click hover"\n\t\t\tdata-title="3G  <span class=\'s-lc-rm-cap-d\'> - </span><span class=\'s-lc-rm-cap-po\'>Capacity: 1.</span></small> " data-content=\'<div class="room_desc">Group Study Room</div>\'></i></div></td></tr><tr class="s-lc-rm-cap-l-1"><td class="s-lc-rm-rntd"><div class="s-lc-rm-rn">3H&nbsp;</div></td><td><div class="s-lc-rm-ttip"><i class="fa fa-info-circle s-lc-rm-pop" tabindex="0" role="button" data-toggle="popover" data-placement="right" data-html="true" data-trigger="click hover"\n\t\t\tdata-title="3H  <span class=\'s-lc-rm-cap-d\'> - </span><span class=\'s-lc-rm-cap-po\'>Capacity: 1.</span></small> " data-content=\'<div class="room_desc">Group Study Room</div>\'></i></div></td></tr><tr class="s-lc-rm-cap-l-1"><td class="s-lc-rm-rntd"><div class="s-lc-rm-rn">3J&nbsp;</div></td><td><div class="s-lc-rm-ttip"><i class="fa fa-info-circle s-lc-rm-pop" tabindex="0" role="button" data-toggle="popover" data-placement="right" data-html="true" data-trigger="click hover"\n\t\t\tdata-title="3J  <span class=\'s-lc-rm-cap-d\'> - </span><span class=\'s-lc-rm-cap-po\'>Capacity: 1.</span></small> " data-content=\'<div class="room_desc">Group Study Room. Knoll furniture evaluation.</div>\'></i></div></td></tr><tr class="s-lc-rm-cap-l-1"><td class="s-lc-rm-rntd"><div class="s-lc-rm-rn">3R&nbsp;</div></td><td><div class="s-lc-rm-ttip"><i class="fa fa-info-circle s-lc-rm-pop" tabindex="0" role="button" data-toggle="popover" data-placement="right" data-html="true" data-trigger="click hover"\n\t\t\tdata-title="3R  <span class=\'s-lc-rm-cap-d\'> - </span><span class=\'s-lc-rm-cap-po\'>Capacity: 1.</span></small> " data-content=\'<div class="room_desc">Group Study Room</div>\'></i></div></td></tr><tr class="s-lc-rm-cap-l-1"><td class="s-lc-rm-rntd"><div class="s-lc-rm-rn">3S&nbsp;</div></td><td><div class="s-lc-rm-ttip"><i class="fa fa-info-circle s-lc-rm-pop" tabindex="0" role="button" data-toggle="popover" data-placement="right" data-html="true" data-trigger="click hover"\n\t\t\tdata-title="3S  <span class=\'s-lc-rm-cap-d\'> - </span><span class=\'s-lc-rm-cap-po\'>Capacity: 1.</span></small> " data-content=\'<div class="room_desc">Group Study Room</div>\'></i></div></td></tr><tr class="s-lc-rm-cap-l-1"><td class="s-lc-rm-rntd"><div class="s-lc-rm-rn">3T&nbsp;</div></td><td><div class="s-lc-rm-ttip"><i class="fa fa-info-circle s-lc-rm-pop" tabindex="0" role="button" data-toggle="popover" data-placement="right" data-html="true" data-trigger="click hover"\n\t\t\tdata-title="3T  <span class=\'s-lc-rm-cap-d\'> - </span><span class=\'s-lc-rm-cap-po\'>Capacity: 1.</span></small> " data-content=\'<div class="room_desc">Group Study Room</div>\'></i></div></td></tr><tr class="s-lc-rm-cap-l-1"><td class="s-lc-rm-rntd"><div class="s-lc-rm-rn">3U&nbsp;</div></td><td><div class="s-lc-rm-tti ...
