# %%
from bs4 import BeautifulSoup

# %%
import pandas as pd

# %%
import requests

# %%
html = requests.get('https://libraries.usc.edu/libraries-hours?week=')

# %%
soup = BeautifulSoup(html.text,'lxml')

# %%
table_list = soup.find_all('table')

# %%
soup
# Out:
# <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML+RDFa 1.0//EN" "http://www.w3.org/MarkUp/DTD/xhtml-rdfa-1.dtd">
# <html dir="ltr" lang="en" prefix="og: http://ogp.me/ns# article: http://ogp.me/ns/article# book: http://ogp.me/ns/book# profile: http://ogp.me/ns/profile# video: http://ogp.me/ns/video# product: http://ogp.me/ns/product# content: http://purl.org/rss/1.0/modules/content/ dc: http://purl.org/dc/terms/ foaf: http://xmlns.com/foaf/0.1/ rdfs: http://www.w3.org/2000/01/rdf-schema# sioc: http://rdfs.org/sioc/ns# sioct: http://rdfs.org/sioc/types# skos: http://www.w3.org/2004/02/skos/core# xsd: http://www.w3.org/2001/XMLSchema#">
# <head profile="http://www.w3.org/1999/xhtml/vocab">
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta charset="utf-8"/>
# <script type="text/javascript">
# //<![CDATA[
# ...

# %%
len(table_list)
# Out:
# 2

# %%
print(type(table_list[0]))
# Out:
# <class 'bs4.element.Tag'>

# %%
table_list[1].content

# %%
lib_hour = pd.read_html(str(table_list[1]))

# %%
lib=lib_hour[0]

# %%
lib
# Out:
#                                  Libraries    SundayJul 16    MondayJul 17  \
# 0                       Accounting Library          Closed       9am - 5pm
# 1       Architecture and Fine Arts Library          Closed       9am - 5pm
# 2                   Cinematic Arts Library          Closed       9am - 5pm
# 3                  Doheny Memorial Library      12pm - 5pm       9am - 8pm
# 4                       East Asian Library      12pm - 5pm       9am - 8pm
# 5                Gaughan & Tiberti Library      12pm - 8pm       9am - 8pm
# 6             Gerontology Library Services          Closed  By Appointment
# 7                     Grand Avenue Library          Closed  By Appointment
# 8              Hoose Library of Philosophy          Closed       9am - 5pm
# 9                              Law Library          Closed       8am - 5pm
# 10                          Leavey Library      12pm - 8pm       9am - 9pm
# ...

# %%
vkc = lib.loc[lib['Libraries'].str.contains('VKC')]

# %%
lib[1:2]
# Out:
#                             Libraries SundayJul 16 MondayJul 17 TuesdayJul 18  \
# 1  Architecture and Fine Arts Library       Closed    9am - 5pm     9am - 5pm
#
#   WednesdayJul 19 ThursdayJul 20 FridayJul 21 SaturdayJul 22
# 1       9am - 5pm      9am - 5pm    9am - 5am         Closed

# %%
for i in lib['Libraries']:
    print(i)
# Out:
# Accounting Library
# Architecture and Fine Arts Library
# Cinematic Arts Library
# Doheny Memorial Library
# East Asian Library
# Gaughan & Tiberti Library
# Gerontology Library Services
# Grand Avenue Library
# Hoose Library of Philosophy
# Law Library
# Leavey Library
# Music Library
# Norris Medical Library
# ONE Archives
# Science & Engineering Library
# Social Work Randall Information Center
# Special Collections
# VKC Library
# Wilson Dental Library
# Wrigley Marine Science Center

# %%
for col in vkc:
    print(vkc[col].values[0])
    print(vkc[col].name)
# Out:
# VKC Library
# Libraries
# Closed
# SundayJul 16
# 9am - 5pm
# MondayJul 17
# 9am - 5pm
# TuesdayJul 18
# 9am - 5pm
# WednesdayJul 19
# 9am - 5pm
# ThursdayJul 20
# 9am - 5pm
# FridayJul 21
# Closed
# SaturdayJul 22
